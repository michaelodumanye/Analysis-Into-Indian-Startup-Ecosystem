# %% [markdown]
# # Indian Start-Up Funding Ecosystem

# %% [markdown]
# ## Business Understanding
# Objective: The primary objective is to venture into the Indian start-up ecosystem. This involves understanding the landscape of start-ups in India, their funding patterns, and the key players in the ecosystem (both start-ups and investors).
#
# Problem Definition: The problem can be defined as analyzing the funding received by Indian start-ups from 2018 to 2021. This involves understanding the trends in funding, identifying the sectors or industries that are attracting the most investment, and recognizing the major investors in the ecosystem.
#
# Data Understanding: The data that will be used for this analysis includes details of the start-ups, the funding amounts they received, and information about the investors. This data will be provided separately for each year from 2018 to 2021 via three different sources.
#
# Plan: The preliminary plan would involve cleaning and preprocessing the data, conducting exploratory data analysis to understand trends and patterns, and possibly building predictive models to forecast future trends in the start-up ecosystem.
#
# Success Criteria: The success of this project could be measured by the team’s ability to gain insights that help in making informed decisions about venturing into the Indian start-up ecosystem. This could involve identifying promising sectors, understanding the competitive landscape, and recognizing potential investment opportunities.
#
# ## Hypothesis Test
#
# Null Hypothesis (H0): There is a difference in funding amount across different sectors.
#
# Alternative Hypothesis (H1): There is no difference in funding amounts across sectors.
#
#
# ## Relevant Questions
# 1. How is funding distributed across different industries?
# 2. Which Indian cities or regions have garnered the highest investments for startups?
# 3. Who are the three primary investors in the Indian startup landscape, and what are their preferred investment sectors?
# 4. What are the burgeoning sectors that are attracting increasing interest from investors?
# 5. Within the top three industries, what are the top three main sectors in terms of funding received?

# %%
# Import requisite libraries
import pyodbc    
from dotenv import dotenv_values
import warnings 
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Importation

# %% [markdown]
# ### Importing and Cleaning 2018 Dataset

# %%
# Access the 2018 dataset
url = 'https://raw.githubusercontent.com/Azubi-Africa/Career_Accelerator_LP1-Data_Analysis/main/startup_funding2018.csv'

dat1 = pd.read_csv(url)
dat1
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount                          Location  \
# ...

# %%
# adding years
year_1 = 2018
dat1['Year'] = year_1

# %%
dat1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
#  6   Year           526 non-null    int64
# dtypes: int64(1), object(6)
# memory usage: 28.9+ KB

# %%
dat1["Amount"].unique()
# Out:
# array(['250000', '₹40,000,000', '₹65,000,000', '2000000', '—', '1600000',
#        '₹16,000,000', '₹50,000,000', '₹100,000,000', '150000', '1100000',
#        '₹500,000', '6000000', '650000', '₹35,000,000', '₹64,000,000',
#        '₹20,000,000', '1000000', '5000000', '4000000', '₹30,000,000',
#        '2800000', '1700000', '1300000', '₹5,000,000', '₹12,500,000',
#        '₹15,000,000', '500000', '₹104,000,000', '₹45,000,000', '13400000',
#        '₹25,000,000', '₹26,400,000', '₹8,000,000', '₹60,000', '9000000',
#        '100000', '20000', '120000', '₹34,000,000', '₹342,000,000',
#        '$143,145', '₹600,000,000', '$742,000,000', '₹1,000,000,000',
#        '₹2,000,000,000', '$3,980,000', '$10,000', '₹100,000',
#        '₹250,000,000', '$1,000,000,000', '$7,000,000', '$35,000,000',
#        '₹550,000,000', '$28,500,000', '$2,000,000', '₹240,000,000',
#        '₹120,000,000', '$2,400,000', '$30,000,000', '₹2,500,000,000',
# ...

# %%
dat1[dat1["Amount"].str.startswith("$")]
# Out:
#                                        Company Name  \
# 86                                              WHR
# 90                                         SBI Life
# 93                 NoPaperForms Solutions Pvt. Ltd.
# 95                                       AuthMetrik
# 101                                          Swiggy
# 102                                      Milkbasket
# 104                                           Toppr
# 106                                 Vivriti Capital
# 108                                     Impact Guru
# 114                                       OneAssist
# 115         Satin Creditcare Network Limited (SCNL)
# 117                                          Moglix
# 119                                     MadGuy Labs
# 122                                         Shop101
# 124                                        Housejoy
# 130                                          BYJU’S
# 134                                     PerkFinance
# ...

# %%
dat1['Amount'] = dat1['Amount'].str.replace(',', '')
dat1
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series     Amount                          Location  \
# ...

# %%
dat1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
#  6   Year           526 non-null    int64
# dtypes: int64(1), object(6)
# memory usage: 28.9+ KB

# %%
# Define a function to convert rupees to dollars
def convert_to_dollars(Amount):
    if Amount.startswith('₹'):
        return float(Amount[1:]) * 0.0146
    else:
        return Amount
 
# Apply the conversion function to the 'amount' column
dat1['Amount'] = dat1['Amount'].apply(convert_to_dollars)
dat1
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series     Amount                          Location  \
# ...

# %%
dat1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
#  6   Year           526 non-null    int64
# dtypes: int64(1), object(6)
# memory usage: 28.9+ KB

# %% [markdown]
# ### Loading and Cleaning 2019 datasets

# %%
# Access the 2019 dataset

dat2 = pd.read_csv('dataset/startup_funding2019.csv')
dat2
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
dat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
# adding years
year_2 = 2019
dat2['Year'] = year_2

# %%
#Renaming amount column in dataset 2#

dat2 = dat2.rename(columns={'Amount($)':'Amount'})
dat2
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
# Define a function to convert rupees to dollars
def convert_to_dollars(Amount):
    if Amount.startswith('₹'):
        return float(Amount[1:]) * 0.0142
    else:
        return Amount
 
# Apply the conversion function to the 'amount' column
dat2['Amount'] = dat2['Amount'].apply(convert_to_dollars)
dat2
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
dat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         89 non-null     object
#  8   Stage          43 non-null     object
#  9   Year           89 non-null     int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 7.1+ KB

# %%
#removing dollar sign
dat2['Amount']= dat2['Amount'].str.replace('$', '')
dat2
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
# remove commas
dat2['Amount']= dat2['Amount'].str.replace(',', '', regex= True)

dat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         89 non-null     object
#  8   Stage          43 non-null     object
#  9   Year           89 non-null     int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 7.1+ KB

# %%
dat2['Amount'].unique()
# Out:
# array(['6300000', '150000000', '28000000', '30000000', '6000000',
#        'Undisclosed', '1000000', '20000000', '275000000', '22000000',
#        '5000000', '140500', '540000000', '15000000', '182700', '12000000',
#        '11000000', '15500000', '1500000', '5500000', '2500000', '140000',
#        '230000000', '49400000', '32000000', '26000000', '150000',
#        '400000', '2000000', '100000000', '8000000', '100000', '50000000',
#        '120000000', '4000000', '6800000', '36000000', '5700000',
#        '25000000', '600000', '70000000', '60000000', '220000', '2800000',
#        '2100000', '7000000', '311000000', '4800000', '693000000',
#        '33000000'], dtype=object)

# %%
dat2_undisclosed = dat2[dat2['Amount']=='Undisclosed']
dat2_undisclosed
# Out:
#                    Company/Brand  Founded HeadQuarter            Sector  \
# 5                       FlytBase      NaN        Pune        Technology
# 6                          Finly      NaN   Bangalore              SaaS
# 10                    Cub McPaws   2010.0      Mumbai   E-commerce & AR
# 14                   Open Secret      NaN         NaN         Food tech
# 19  Azah Personal Care Pvt. Ltd.   2018.0    Gurugram            Health
# 23            DROR Labs Pvt. Ltd   2018.0       Delhi       Safety tech
# 32                      Pumpkart   2014.0  Chandigarh     E-marketplace
# 45                        Afinoz      NaN       Noida           Fintech
# 54                     Ninjacart   2015.0         NaN  B2B Supply Chain
# 55                   Binca Games   2014.0      Mumbai             Games
# 65                  Cubical Labs   2013.0         NaN               IoT
# 75                      Sportido   2015.0       Noida            Sports
#
# ...

# %%
# save undisclosed data in a csv
dat2_undisclosed.to_csv('../analysis-into-indian-startup-ecosystem/dataset/undisclosed_amount_data.csv', index=False)

# %%
dat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         89 non-null     object
#  8   Stage          43 non-null     object
#  9   Year           89 non-null     int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 7.1+ KB

# %%
dat2 = dat2[dat2['Amount']!='Undisclosed']
dat2['Amount'].unique()
# Out:
# array(['6300000', '150000000', '28000000', '30000000', '6000000',
#        '1000000', '20000000', '275000000', '22000000', '5000000',
#        '140500', '540000000', '15000000', '182700', '12000000',
#        '11000000', '15500000', '1500000', '5500000', '2500000', '140000',
#        '230000000', '49400000', '32000000', '26000000', '150000',
#        '400000', '2000000', '100000000', '8000000', '100000', '50000000',
#        '120000000', '4000000', '6800000', '36000000', '5700000',
#        '25000000', '600000', '70000000', '60000000', '220000', '2800000',
#        '2100000', '7000000', '311000000', '4800000', '693000000',
#        '33000000'], dtype=object)

# %%
dat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  77 non-null     object
#  1   Founded        52 non-null     float64
#  2   HeadQuarter    61 non-null     object
#  3   Sector         72 non-null     object
#  4   What it does   77 non-null     object
#  5   Founders       74 non-null     object
#  6   Investor       77 non-null     object
#  7   Amount         77 non-null     object
#  8   Stage          40 non-null     object
#  9   Year           77 non-null     int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 6.6+ KB

# %%
# convert amount to float
dat2['Amount']= dat2['Amount'].astype(float)
dat2
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %% [markdown]
# ### Importing and cleaning 2020 and 2021 datasets

# %%
# Load environment variables from .env file into a dictionary
environment_variables = dotenv_values('.env')

# Get the values for the credentials you set in the '.env' file
server = environment_variables.get("SERVER_NAME")
database = environment_variables.get("DATABASE_NAME")
username = environment_variables.get("DB_USERNAME")
password = environment_variables.get("PASSWORD")

# %%
connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password};MARS_Connection=yes;MinProtocolVersion=TLSv1.2;"

# %%
connection = pyodbc.connect(connection_string)

# %%
# select data from 2020
query = "SELECT * FROM LP1_startup_funding2020"

dat3 = pd.read_sql(query, connection)
dat3.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
dat3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.5+ KB

# %%
# adding years
year_3 = 2020
dat3['Year'] = year_3
dat3
# Out:
#      Company_Brand  Founded HeadQuarter              Sector  \
# 0       Aqgromalin   2019.0     Chennai            AgriTech
# 1         Krayonnz   2019.0   Bangalore              EdTech
# 2     PadCare Labs   2018.0        Pune  Hygiene management
# 3            NCOME   2020.0   New Delhi              Escrow
# 4       Gramophone   2016.0      Indore            AgriTech
# ...            ...      ...         ...                 ...
# 1050  Leverage Edu      NaN       Delhi              Edtech
# 1051         EpiFi      NaN        None             Fintech
# 1052       Purplle   2012.0      Mumbai           Cosmetics
# 1053        Shuttl   2015.0       Delhi           Transport
# 1054         Pando   2017.0     Chennai            Logitech
#
#                                            What_it_does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %%
# loading data from 2021
query = "SELECT * FROM LP1_startup_funding2021"

dat4 = pd.read_sql(query, connection)
dat4.head()
# Out:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# ...

# %%
# adding years
year_4 = 2021
dat4['Year'] = year_4
dat4
# Out:
#        Company_Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What_it_does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
dat4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
#  9   Year           1209 non-null   int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 94.6+ KB

# %%
dat3=dat3.drop('column10', axis=1)
dat3
# Out:
#      Company_Brand  Founded HeadQuarter              Sector  \
# 0       Aqgromalin   2019.0     Chennai            AgriTech
# 1         Krayonnz   2019.0   Bangalore              EdTech
# 2     PadCare Labs   2018.0        Pune  Hygiene management
# 3            NCOME   2020.0   New Delhi              Escrow
# 4       Gramophone   2016.0      Indore            AgriTech
# ...            ...      ...         ...                 ...
# 1050  Leverage Edu      NaN       Delhi              Edtech
# 1051         EpiFi      NaN        None             Fintech
# 1052       Purplle   2012.0      Mumbai           Cosmetics
# 1053        Shuttl   2015.0       Delhi           Transport
# 1054         Pando   2017.0     Chennai            Logitech
#
#                                            What_it_does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %% [markdown]
# ## Merging datasets

# %%
#merging 2020 and 2021 datasets
merged_table= pd.concat([dat3, dat4], ignore_index=True)
merged_table
# Out:
#      Company_Brand  Founded HeadQuarter                 Sector  \
# 0       Aqgromalin   2019.0     Chennai               AgriTech
# 1         Krayonnz   2019.0   Bangalore                 EdTech
# 2     PadCare Labs   2018.0        Pune     Hygiene management
# 3            NCOME   2020.0   New Delhi                 Escrow
# 4       Gramophone   2016.0      Indore               AgriTech
# ...            ...      ...         ...                    ...
# 2259      Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 2260        Vahdam   2015.0   New Delhi       Food & Beverages
# 2261  Leap Finance   2019.0   Bangalore     Financial Services
# 2262  CollegeDekho   2015.0    Gurugram                 EdTech
# 2263        WeRize   2019.0   Bangalore     Financial Services
#
#                                            What_it_does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# ...

# %%
#renaming company name columns
dat1.rename(columns={'Company Name':'Company_Brand'}, inplace= True)

dat2.rename(columns={'Company/Brand':'Company_Brand'}, inplace= True)

# %%
#renaming round/series to name columns
dat1.rename(columns={'Round/Series':'Stage'}, inplace= True)

# %%
#renaming Industry to name Sector
dat1.rename(columns={'Industry':'Sector'}, inplace= True)

# %%
#renaming Industry to name Sector
dat1.rename(columns={'About Company':'What it does'}, inplace= True)

# %%
#renaming Industry to name Sector
dat1.rename(columns={'Location':'HeadQuarter'}, inplace= True)

# %%
# extracting the locations in dat1
dat1['HeadQuarter']= dat1['HeadQuarter'].str.split(',').str[0]

# %%
#printing columns to compare if the column names are matching
print(dat1.columns)
print(dat2.columns)
print(merged_table.columns)
# Out:
# Index(['Company_Brand', 'Sector', 'Stage', 'Amount', 'HeadQuarter',
#        'What it does', 'Year'],
#       dtype='object')
# Index(['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'Year'],
#       dtype='object')
# Index(['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'Year'],
#       dtype='object')

# %%
dat1.head(3)
# Out:
#      Company_Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
#
#       Stage    Amount HeadQuarter  \
# 0      Seed    250000   Bangalore
# 1      Seed  584000.0      Mumbai
# 2  Series A  949000.0     Gurgaon
#
#                                         What it does  Year
# 0  TheCollegeFever is a hub for fun, fiesta and f...  2018
# 1  A startup which aggregates milk from dairy far...  2018
# 2          Leading Online Loans Marketplace in India  2018

# %%
dat2['HeadQuarter'].unique()
# Out:
# array([nan, 'Mumbai', 'Chennai', 'Telangana', 'Noida', 'Delhi',
#        'Bangalore', 'Ahmedabad', 'Haryana', 'Gurugram', 'Jaipur', 'Pune',
#        'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad', 'Rajasthan'],
#       dtype=object)

# %%
dat2.head(3)
# Out:
#     Company_Brand  Founded HeadQuarter     Sector  \
# 0  Bombay Shaving      NaN         NaN  Ecommerce
# 1       Ruangguru   2014.0      Mumbai     Edtech
# 2        Eduisfun      NaN      Mumbai     Edtech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
#
#                                          Investor       Amount          Stage  \
# 0                            Sixth Sense Ventures    6300000.0            NaN
# 1                                General Atlantic  150000000.0       Series C
# 2  Deepak Parekh, Amitabh Bachchan, Piyush Pandey   28000000.0  Fresh funding
#
#    Year
# 0  2019
# 1  2019
# 2  2019

# %%
merged_table.head(3)
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
#
#                            Founders         Investor    Amount     Stage  Year
# 0   Prasanna Manogaran, Bharani C L  Angel investors  200000.0      None  2020
# 1  Saurabh Dixit, Gurudutt Upadhyay  GSF Accelerator  100000.0  Pre-seed  2020
# 2                   Ajinkya Dhariya   Venture Center       NaN  Pre-seed  2020

# %%
merged_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2264 non-null   object
#  1   Founded        2050 non-null   float64
#  2   HeadQuarter    2169 non-null   object
#  3   Sector         2251 non-null   object
#  4   What_it_does   2264 non-null   object
#  5   Founders       2248 non-null   object
#  6   Investor       2164 non-null   object
#  7   Amount         2007 non-null   object
#  8   Stage          1372 non-null   object
#  9   Year           2264 non-null   int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 177.0+ KB

# %%
#renaming What_it_does to What it does
merged_table.rename(columns={'What_it_does':'What it does'}, inplace= True)
merged_table
# Out:
#      Company_Brand  Founded HeadQuarter                 Sector  \
# 0       Aqgromalin   2019.0     Chennai               AgriTech
# 1         Krayonnz   2019.0   Bangalore                 EdTech
# 2     PadCare Labs   2018.0        Pune     Hygiene management
# 3            NCOME   2020.0   New Delhi                 Escrow
# 4       Gramophone   2016.0      Indore               AgriTech
# ...            ...      ...         ...                    ...
# 2259      Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 2260        Vahdam   2015.0   New Delhi       Food & Beverages
# 2261  Leap Finance   2019.0   Bangalore     Financial Services
# 2262  CollegeDekho   2015.0    Gurugram                 EdTech
# 2263        WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# ...

# %%
#merging 2019,2020,2021
merger= pd.concat([dat2, merged_table], ignore_index=True)
merger
# Out:
#        Company_Brand  Founded HeadQuarter                 Sector  \
# 0     Bombay Shaving      NaN         NaN              Ecommerce
# 1          Ruangguru   2014.0      Mumbai                 Edtech
# 2           Eduisfun      NaN      Mumbai                 Edtech
# 3           HomeLane   2014.0     Chennai        Interior design
# 4           Nu Genes   2004.0   Telangana               AgriTech
# ...              ...      ...         ...                    ...
# 2336        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 2337          Vahdam   2015.0   New Delhi       Food & Beverages
# 2338    Leap Finance   2019.0   Bangalore     Financial Services
# 2339    CollegeDekho   2015.0    Gurugram                 EdTech
# 2340          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 0            Provides a range of male grooming products
# 1     A learning platform that provides topic-based ...
# ...

# %%
merger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2341 entries, 0 to 2340
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2341 non-null   object
#  1   Founded        2102 non-null   float64
#  2   HeadQuarter    2230 non-null   object
#  3   Sector         2323 non-null   object
#  4   What it does   2341 non-null   object
#  5   Founders       2322 non-null   object
#  6   Investor       2241 non-null   object
#  7   Amount         2084 non-null   object
#  8   Stage          1412 non-null   object
#  9   Year           2341 non-null   int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 183.0+ KB

# %%
#merging 2018,2019,2020,2021
data_df= pd.concat([dat1, merger], ignore_index=True)
data_df
# Out:
#         Company_Brand                                             Sector  \
# 0     TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1     Happy Cow Dairy                               Agriculture, Farming
# 2          MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3         PayMe India                        Financial Services, FinTech
# 4            Eunimart                 E-Commerce Platforms, Retail, SaaS
# ...               ...                                                ...
# 2862         Gigforce                              Staffing & Recruiting
# 2863           Vahdam                                   Food & Beverages
# 2864     Leap Finance                                 Financial Services
# 2865     CollegeDekho                                             EdTech
# 2866           WeRize                                 Financial Services
#
#              Stage     Amount HeadQuarter  \
# 0             Seed     250000   Bangalore
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2867 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2867 non-null   object
#  1   Sector         2849 non-null   object
#  2   Stage          1938 non-null   object
#  3   Amount         2610 non-null   object
#  4   HeadQuarter    2756 non-null   object
#  5   What it does   2867 non-null   object
#  6   Year           2867 non-null   int64
#  7   Founded        2102 non-null   float64
#  8   Founders       2322 non-null   object
#  9   Investor       2241 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 224.1+ KB

# %% [markdown]
# ### Data Cleaning by Columns

# %% [markdown]
# ### Cleaning Amount Column

# %%
data_df['Amount'].unique()
# Out:
# array(['250000', 584000.0, 949000.0, '2000000', '—', '1600000', 233600.0,
#        730000.0, 1460000.0, '150000', '1100000', 7300.0, '6000000',
#        '650000', 511000.0, 934400.0, 292000.0, '1000000', '5000000',
#        '4000000', 438000.0, '2800000', '1700000', '1300000', 73000.0,
#        182500.0, 219000.0, '500000', 1518400.0, 657000.0, '13400000',
#        365000.0, 385440.0, 116800.0, 876.0, '9000000', '100000', '20000',
#        '120000', 496400.0, 4993200.0, '$143145', 8760000.0, '$742000000',
#        14600000.0, 29200000.0, '$3980000', '$10000', 1460.0, 3650000.0,
#        '$1000000000', '$7000000', '$35000000', 8030000.0, '$28500000',
#        '$2000000', 3504000.0, 1752000.0, '$2400000', '$30000000',
#        36500000.0, '$23000000', '$150000', '$11000000', 642400.0,
#        '$3240000', 876000.0, '$540000000', 9490000.0, 23360000.0,
#        '$900000', '$10000000', '$1500000', 1022000.0, '$1000000',
#        '$5000000', '$14000000', 1496500.0, '$100000000', 17520.0,
# ...

# %%
# removing the $
data_df['Amount']= data_df['Amount'].apply(lambda x:str(x).replace('$',''))

# .apply(lambda x:str(x).replace('$','')
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2867 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2867 non-null   object
#  1   Sector         2849 non-null   object
#  2   Stage          1938 non-null   object
#  3   Amount         2867 non-null   object
#  4   HeadQuarter    2756 non-null   object
#  5   What it does   2867 non-null   object
#  6   Year           2867 non-null   int64
#  7   Founded        2102 non-null   float64
#  8   Founders       2322 non-null   object
#  9   Investor       2241 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 224.1+ KB

# %%
data_df['Amount'].unique()
# Out:
# array(['250000', 584000.0, 949000.0, '2000000', '—', '1600000', 233600.0,
#        730000.0, 1460000.0, '150000', '1100000', 7300.0, '6000000',
#        '650000', 511000.0, 934400.0, 292000.0, '1000000', '5000000',
#        '4000000', 438000.0, '2800000', '1700000', '1300000', 73000.0,
#        182500.0, 219000.0, '500000', 1518400.0, 657000.0, '13400000',
#        365000.0, 385440.0, 116800.0, 876.0, '9000000', '100000', '20000',
#        '120000', 496400.0, 4993200.0, '$143145', 8760000.0, '$742000000',
#        14600000.0, 29200000.0, '$3980000', '$10000', 1460.0, 3650000.0,
#        '$1000000000', '$7000000', '$35000000', 8030000.0, '$28500000',
#        '$2000000', 3504000.0, 1752000.0, '$2400000', '$30000000',
#        36500000.0, '$23000000', '$150000', '$11000000', 642400.0,
#        '$3240000', 876000.0, '$540000000', 9490000.0, 23360000.0,
#        '$900000', '$10000000', '$1500000', 1022000.0, '$1000000',
#        '$5000000', '$14000000', 1496500.0, '$100000000', 17520.0,
# ...

# %%
data_df['Amount'].unique()
# Out:
# array(['250000', 584000.0, 949000.0, '2000000', '—', '1600000', 233600.0,
#        730000.0, 1460000.0, '150000', '1100000', 7300.0, '6000000',
#        '650000', 511000.0, 934400.0, 292000.0, '1000000', '5000000',
#        '4000000', 438000.0, '2800000', '1700000', '1300000', 73000.0,
#        182500.0, 219000.0, '500000', 1518400.0, 657000.0, '13400000',
#        365000.0, 385440.0, 116800.0, 876.0, '9000000', '100000', '20000',
#        '120000', 496400.0, 4993200.0, '$143145', 8760000.0, '$742000000',
#        14600000.0, 29200000.0, '$3980000', '$10000', 1460.0, 3650000.0,
#        '$1000000000', '$7000000', '$35000000', 8030000.0, '$28500000',
#        '$2000000', 3504000.0, 1752000.0, '$2400000', '$30000000',
#        36500000.0, '$23000000', '$150000', '$11000000', 642400.0,
#        '$3240000', 876000.0, '$540000000', 9490000.0, 23360000.0,
#        '$900000', '$10000000', '$1500000', 1022000.0, '$1000000',
#        '$5000000', '$14000000', 1496500.0, '$100000000', 17520.0,
# ...

# %%
# removing the $
data_df['Amount']= data_df['Amount'].apply(lambda x:str(x).replace(',',''))

# .apply(lambda x:str(x).replace(',','')
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2867 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2867 non-null   object
#  1   Sector         2849 non-null   object
#  2   Stage          1938 non-null   object
#  3   Amount         2867 non-null   object
#  4   HeadQuarter    2756 non-null   object
#  5   What it does   2867 non-null   object
#  6   Year           2867 non-null   int64
#  7   Founded        2102 non-null   float64
#  8   Founders       2322 non-null   object
#  9   Investor       2241 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 224.1+ KB

# %%
# Filter the records where the amount column contains 'undisclosed'
undisclosed_data = data_df[data_df['Amount'] == 'Undisclosed']
undisclosed_data
# Out:
#                 Company_Brand                 Sector         Stage  \
# 1665              Qube Health             HealthTech  Pre-series A
# 1666                 Vitra.ai           Tech Startup          None
# 1679                    Uable                 EdTech          Seed
# 1697                 TruNativ       Food & Beverages          Seed
# 1712                   AntWak                 EdTech          Seed
# 1722              Rage Coffee       Food & Beverages  Pre-series A
# 1725                    Kudos                FinTech  Pre-series A
# 1974                Hubhopper                Podcast          None
# 1977            Battery Smart                Battery          Seed
# 1979                  Onelife             Healthcare          None
# 1983                    Aisle                 Dating  Pre-series A
# 1992                  Zingbus         Transportation  Pre-series A
# 1994                 Codingal                 EdTech          None
# ...

# %%
undisclosed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 116 entries, 1665 to 2851
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  116 non-null    object
#  1   Sector         116 non-null    object
#  2   Stage          59 non-null     object
#  3   Amount         116 non-null    object
#  4   HeadQuarter    116 non-null    object
#  5   What it does   116 non-null    object
#  6   Year           116 non-null    int64
#  7   Founded        116 non-null    float64
#  8   Founders       116 non-null    object
#  9   Investor       111 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 10.0+ KB

# %%
# Remove the undisclosed records from Data_df
data_df = data_df[data_df['Amount']!='Undisclosed']
data_df['Amount'].unique()
# Out:
# array(['250000', 584000.0, 949000.0, '2000000', '—', '1600000', 233600.0,
#        730000.0, 1460000.0, '150000', '1100000', 7300.0, '6000000',
#        '650000', 511000.0, 934400.0, 292000.0, '1000000', '5000000',
#        '4000000', 438000.0, '2800000', '1700000', '1300000', 73000.0,
#        182500.0, 219000.0, '500000', 1518400.0, 657000.0, '13400000',
#        365000.0, 385440.0, 116800.0, 876.0, '9000000', '100000', '20000',
#        '120000', 496400.0, 4993200.0, '$143145', 8760000.0, '$742000000',
#        14600000.0, 29200000.0, '$3980000', '$10000', 1460.0, 3650000.0,
#        '$1000000000', '$7000000', '$35000000', 8030000.0, '$28500000',
#        '$2000000', 3504000.0, 1752000.0, '$2400000', '$30000000',
#        36500000.0, '$23000000', '$150000', '$11000000', 642400.0,
#        '$3240000', 876000.0, '$540000000', 9490000.0, 23360000.0,
#        '$900000', '$10000000', '$1500000', 1022000.0, '$1000000',
#        '$5000000', '$14000000', 1496500.0, '$100000000', 17520.0,
# ...

# %%
# checking data that has amount has upsparks
data_df[data_df['Amount'] == 'Upsparks']
# Out:
#      Company_Brand          Sector     Stage    Amount     HeadQuarter  \
# 1756       FanPlay  Computer Games  $1200000  Upsparks  Computer Games
# 1769       FanPlay  Computer Games  $1200000  Upsparks  Computer Games
#
#                                            What it does  Year  Founded  \
# 1756  A real money game app specializing in trivia g...  2021   2020.0
# 1769  A real money game app specializing in trivia g...  2021   2020.0
#
#      Founders                     Investor
# 1756   YC W21  Pritesh Kumar, Bharat Gupta
# 1769   YC W21  Pritesh Kumar, Bharat Gupta

# %% [markdown]
# ###### the script above printed two rows which are duplicates. so one of them were going to actually be removed
# ###### then the data in the following columns ; Sector, stage, Amount and Headquarters do not give enough justification to keep

# %%
data_df = data_df[data_df['Amount'] != 'Upsparks']

# %%
# Remove dashes from the 'Amount' column
data_df['Amount'] = data_df['Amount'].replace('—', '')
data_df['Amount'].unique()
# Out:
# array(['250000', 584000.0, 949000.0, '2000000', '', '1600000', 233600.0,
#        730000.0, 1460000.0, '150000', '1100000', 7300.0, '6000000',
#        '650000', 511000.0, 934400.0, 292000.0, '1000000', '5000000',
#        '4000000', 438000.0, '2800000', '1700000', '1300000', 73000.0,
#        182500.0, 219000.0, '500000', 1518400.0, 657000.0, '13400000',
#        365000.0, 385440.0, 116800.0, 876.0, '9000000', '100000', '20000',
#        '120000', 496400.0, 4993200.0, '$143145', 8760000.0, '$742000000',
#        14600000.0, 29200000.0, '$3980000', '$10000', 1460.0, 3650000.0,
#        '$1000000000', '$7000000', '$35000000', 8030000.0, '$28500000',
#        '$2000000', 3504000.0, 1752000.0, '$2400000', '$30000000',
#        36500000.0, '$23000000', '$150000', '$11000000', 642400.0,
#        '$3240000', 876000.0, '$540000000', 9490000.0, 23360000.0,
#        '$900000', '$10000000', '$1500000', 1022000.0, '$1000000',
#        '$5000000', '$14000000', 1496500.0, '$100000000', 17520.0,
# ...

# %%
# Remove space from the 'Amount' column and convert to 0
data_df['Amount'] = data_df['Amount'].replace('', 0)
data_df['Amount'].unique()
# Out:
# array(['250000', '584000.0', '949000.0', '2000000', 0, '1600000',
#        '233600.0', '730000.0', '1460000.0', '150000', '1100000', '7300.0',
#        '6000000', '650000', '511000.0', '934400.0', '292000.0', '1000000',
#        '5000000', '4000000', '438000.0', '2800000', '1700000', '1300000',
#        '73000.0', '182500.0', '219000.0', '500000', '1518400.0',
#        '657000.0', '13400000', '365000.0', '385440.0', '116800.0',
#        '876.0', '9000000', '100000', '20000', '120000', '496400.0',
#        '4993200.0', '143145', '8760000.0', '742000000', '14600000.0',
#        '29200000.0', '3980000', '10000', '1460.0', '3650000.0',
#        '1000000000', '7000000', '35000000', '8030000.0', '28500000',
#        '3504000.0', '1752000.0', '2400000', '30000000', '36500000.0',
#        '23000000', '11000000', '642400.0', '3240000', '876000.0',
#        '540000000', '9490000.0', '23360000.0', '900000', '10000000',
#        '1500000', '1022000.0', '14000000', '1496500.0', '100000000',
# ...

# %%
#removing Series C from Amount column
data_df[data_df['Amount'] == 'Series C']
# Out:
#            Company_Brand                                             Sector  \
# 1900  Fullife Healthcare  Primary Business is Development and Manufactur...
# 1914  Fullife Healthcare  Primary Business is Development and Manufactur...
#
#      Stage    Amount             HeadQuarter  What it does  Year  Founded  \
# 1900  None  Series C  Pharmaceuticals\t#REF!  Varun Khanna  2021   2009.0
# 1914  None  Series C  Pharmaceuticals\t#REF!  Varun Khanna  2021   2009.0
#
#                                 Founders   Investor
# 1900  Morgan Stanley Private Equity Asia  $22000000
# 1914  Morgan Stanley Private Equity Asia  $22000000

# %%
# Remove rows where the 'Amount' column is equal to 'Series C'
# These rows have been mislabeled and are duplicated.
data_df = data_df[data_df['Amount'] != 'Series C']

# %%
data_df[data_df['Amount'] == 'Seed']
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
# Remove rows where the 'Amount' column is equal to 'Seed'
# These rows have been mislabeled 
data_df = data_df[data_df['Amount'] != 'Seed']

# %%
# Convert undisclosed_data to DataFrame if it's not already
if not isinstance(undisclosed_data, pd.DataFrame):
    undisclosed_data = pd.DataFrame(undisclosed_data)

# Filter the additional records where the amount column contains 'Undisclosed' (both capital and lowercase)
additional_undisclosed_data = data_df[data_df['Amount'].str.lower() == 'undisclosed']

# Append the additional undisclosed records to the existing undisclosed_data
undisclosed_data = pd.concat([undisclosed_data, additional_undisclosed_data], ignore_index=True)

# %%
#remove undisclosed from amount
data_df=  data_df[data_df['Amount'].str.lower() != 'undisclosed']
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2721 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2721 non-null   object
#  1   Sector         2703 non-null   object
#  2   Stage          1862 non-null   object
#  3   Amount         2464 non-null   object
#  4   HeadQuarter    2610 non-null   object
#  5   What it does   2721 non-null   object
#  6   Year           2721 non-null   int64
#  7   Founded        1956 non-null   float64
#  8   Founders       2176 non-null   object
#  9   Investor       2101 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 233.8+ KB

# %%
data_df[data_df['Amount'] == 'ah! Ventures']
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
#remove ah! Ventures from amount
data_df=  data_df[data_df['Amount'] != 'ah! Ventures']
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2721 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2721 non-null   object
#  1   Sector         2703 non-null   object
#  2   Stage          1862 non-null   object
#  3   Amount         2464 non-null   object
#  4   HeadQuarter    2610 non-null   object
#  5   What it does   2721 non-null   object
#  6   Year           2721 non-null   int64
#  7   Founded        1956 non-null   float64
#  8   Founders       2176 non-null   object
#  9   Investor       2101 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 233.8+ KB

# %%
data_df[data_df['Amount'] == 'Pre-series A']
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
#remove ah! Ventures from amount
data_df=  data_df[data_df['Amount'] != 'Pre-series A']
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2816 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2816 non-null   object
#  1   Sector         2798 non-null   object
#  2   Stage          1908 non-null   object
#  3   Amount         2559 non-null   object
#  4   HeadQuarter    2705 non-null   object
#  5   What it does   2816 non-null   object
#  6   Year           2816 non-null   int64
#  7   Founded        2051 non-null   float64
#  8   Founders       2271 non-null   object
#  9   Investor       2191 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 242.0+ KB

# %%
data_df[data_df['Amount'] == 'ITO Angel Network LetsVenture']
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
#remove ITO Angel Network LetsVenture from amount
data_df=  data_df[data_df['Amount'] != 'ITO Angel Network LetsVenture']
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2721 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2721 non-null   object
#  1   Sector         2703 non-null   object
#  2   Stage          1862 non-null   object
#  3   Amount         2464 non-null   object
#  4   HeadQuarter    2610 non-null   object
#  5   What it does   2721 non-null   object
#  6   Year           2721 non-null   int64
#  7   Founded        1956 non-null   float64
#  8   Founders       2176 non-null   object
#  9   Investor       2101 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 233.8+ KB

# %%
data_df[data_df['Amount'] == 'JITO Angel Network LetsVenture']
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
#remove ITO Angel Network LetsVenture from amount
data_df=  data_df[data_df['Amount'] != 'JITO Angel Network LetsVenture']
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2721 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2721 non-null   object
#  1   Sector         2703 non-null   object
#  2   Stage          1862 non-null   object
#  3   Amount         2464 non-null   object
#  4   HeadQuarter    2610 non-null   object
#  5   What it does   2721 non-null   object
#  6   Year           2721 non-null   int64
#  7   Founded        1956 non-null   float64
#  8   Founders       2176 non-null   object
#  9   Investor       2101 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 233.8+ KB

# %%
data_df['Amount'].unique()
# Out:
# array(['250000', '584000.0', '949000.0', '2000000', '', '1600000',
#        '233600.0', '730000.0', '1460000.0', '150000', '1100000', '7300.0',
#        '6000000', '650000', '511000.0', '934400.0', '292000.0', '1000000',
#        '5000000', '4000000', '438000.0', '2800000', '1700000', '1300000',
#        '73000.0', '182500.0', '219000.0', '500000', '1518400.0',
#        '657000.0', '13400000', '365000.0', '385440.0', '116800.0',
#        '876.0', '9000000', '100000', '20000', '120000', '496400.0',
#        '4993200.0', '143145', '8760000.0', '742000000', '14600000.0',
#        '29200000.0', '3980000', '10000', '1460.0', '3650000.0',
#        '1000000000', '7000000', '35000000', '8030000.0', '28500000',
#        '3504000.0', '1752000.0', '2400000', '30000000', '36500000.0',
#        '23000000', '11000000', '642400.0', '3240000', '876000.0',
#        '540000000', '9490000.0', '23360000.0', '900000', '10000000',
#        '1500000', '1022000.0', '14000000', '1496500.0', '100000000',
# ...

# %%
data_df['Amount'].isna().sum()
# Out:
# 257

# %%
data_df[data_df['Amount'] == 'None']
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
data_df = data_df[data_df['Amount'] != 'None']
data_df[data_df['Amount'] == 'None']
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2721 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2721 non-null   object
#  1   Sector         2703 non-null   object
#  2   Stage          1862 non-null   object
#  3   Amount         2464 non-null   object
#  4   HeadQuarter    2610 non-null   object
#  5   What it does   2721 non-null   object
#  6   Year           2721 non-null   int64
#  7   Founded        1956 non-null   float64
#  8   Founders       2176 non-null   object
#  9   Investor       2101 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 233.8+ KB

# %%
# Remove non-numeric characters and the dollar sign ('$')
data_df['Amount'] = data_df['Amount'].apply(lambda x: str(x).replace('$', '') if pd.notna(x) else x)

# %%
# Replace empty strings with NaN
data_df['Amount'] = pd.to_numeric(data_df['Amount'], errors='coerce')

# Convert 'Amount' column to float
data_df['Amount'] = data_df['Amount'].astype(float)

# Check the information of the DataFrame
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2721 entries, 0 to 2866
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2721 non-null   object
#  1   Sector         2703 non-null   object
#  2   Stage          1862 non-null   object
#  3   Amount         1969 non-null   float64
#  4   HeadQuarter    2610 non-null   object
#  5   What it does   2721 non-null   object
#  6   Year           2721 non-null   int64
#  7   Founded        1956 non-null   float64
#  8   Founders       2176 non-null   object
#  9   Investor       2101 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 233.8+ KB

# %% [markdown]
# ### Cleaning the Company_Brand column

# %%
# Get unique values in the Company_Brand column and sort them
sorted(data_df['Company_Brand'].unique())
# Out:
# ['&ME',
#  '1Bridge',
#  '1Crowd',
#  '1K Kirana Bazaar',
#  '1MG',
#  '21K School',
#  '3SC',
#  '3one4 Capital',
#  '4Fin',
#  '4baseCare',
#  '5C Network',
#  '6Degree',
#  '88academics',
#  '8i Ventures',
#  '90+ My Tuition App',
#  '91springboard',
#  '9stacks',
#  'ABL Workspaces',
#  'ACKO',
#  'AFK Gaming',
#  'AMPM',
#  'ANS Commerce',
#  'ANSR',
#  'APAC Financial Services',
#  'ASQI Advisors',
#  'Aadhar',
#  'Aagey',
#  'Aarav Unmanned Systems',
#  'Aashiyaan Housing and Development Finance',
#  'Aavas Financiers',
#  'Aavenir',
#  'Able Jobs',
#  'Acculi Labs',
#  'AcknoLedger',
#  'Acko',
#  'Acko General Insurance',
#  'Adda247',
#  'Adiuvo Diagnostics',
#  'AdonMo',
#  'Advantage Club',
#  'Aerchain',
#  'Aerostrovilos',
#  'Aesthetic Nutrition',
#  'Aether Biomedical',
#  'AgNext',
#  'AgNext Technologies',
#  'Agnikul',
#  'Agricxlab Private Limited',
#  'Agrix',
#  'Agro2o',
#  'AgroStar',
#  'AgroWave',
#  'Ahaguru',
#  'Aibono',
#  'Airblack',
#  'Airmeet',
# ...

# %%
# Get unique values in the Company_Brand column
unique_company_brands = data_df['Company_Brand'].unique()

# Convert the unique values array to a list
unique_company_brands_list = unique_company_brands.tolist()

# Print the list of unique company brands
unique_company_brands_list
# Out:
# ['TheCollegeFever',
#  'Happy Cow Dairy',
#  'MyLoanCare',
#  'PayMe India',
#  'Eunimart',
#  'Hasura',
#  'Tripshelf',
#  'Hyperdata.IO',
#  'Freightwalla',
#  'Microchip Payments',
#  'BizCrum Infotech Pvt. Ltd.',
#  'Emojifi',
#  'Flock',
#  'Freshboxx',
#  'Wide Mobility Mechatronics',
#  'Pitstop',
#  'Mihuru',
#  'Fyle',
#  'AppWharf',
#  'Antariksh Waste Ventures Pvt ltd',
#  'Cogoport',
#  'PaisaDukan',
#  'Sleepy Owl Coffee',
#  'BlueJack',
#  'PregBuddy',
#  'AgNext Technologies',
#  'Pando',
#  'Mintifi',
#  'Carcrew',
#  'NicheAI',
#  'Chariot Tech',
#  'Ideal Insurance Brokers/ 121Policy.com',
#  'Loanzen',
#  'Mojro Technologies',
#  'Elemential',
#  'Loadshare',
#  'Yumlane',
#  'Kriger Campus',
#  'Pipa+Bella',
#  'Kaleidofin',
#  'Chakr Innovation',
#  'IndigoLearn',
#  'UClean',
#  'Coutloot',
#  'Letstrack',
#  'Pooltoo',
#  'Finzy',
#  'Fitternity',
#  'Keito',
#  'Tolet for Students',
#  'Chai Kings',
#  'Dainik Jagran',
#  'Playtoome',
#  'ONGO Framework',
# ...

# %% [markdown]
# ### Cleaning the Sector column

# %%
data_df['Sector'].unique()
# Out:
# array(['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing',
#        'Agriculture, Farming',
#        'Credit, Financial Services, Lending, Marketplace',
#        'Financial Services, FinTech',
#        'E-Commerce Platforms, Retail, SaaS',
#        'Cloud Infrastructure, PaaS, SaaS',
#        'Internet, Leisure, Marketplace', 'Market Research',
#        'Information Services, Information Technology', 'Mobile Payments',
#        'B2B, Shoes', 'Internet',
#        'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat',
#        'Food Delivery', 'Industrial Automation',
#        'Automotive, Search Engine, Service Industry',
#        'Finance, Internet, Travel',
#        'Accounting, Business Information Systems, Business Travel, Finance, SaaS',
#        'Artificial Intelligence, Product Search, SaaS, Service Industry, Software',
#        'Internet of Things, Waste Management',
# ...

# %%
# Get unique values in the Company_Brand column
unique_sectors = data_df['Sector'].unique()

# Convert the unique values array to a list
unique_sectors_list = unique_sectors.tolist()

# Print the list of unique company brands
unique_sectors_list
# Out:
# ['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing',
#  'Agriculture, Farming',
#  'Credit, Financial Services, Lending, Marketplace',
#  'Financial Services, FinTech',
#  'E-Commerce Platforms, Retail, SaaS',
#  'Cloud Infrastructure, PaaS, SaaS',
#  'Internet, Leisure, Marketplace',
#  'Market Research',
#  'Information Services, Information Technology',
#  'Mobile Payments',
#  'B2B, Shoes',
#  'Internet',
#  'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat',
#  'Food Delivery',
#  'Industrial Automation',
#  'Automotive, Search Engine, Service Industry',
#  'Finance, Internet, Travel',
#  'Accounting, Business Information Systems, Business Travel, Finance, SaaS',
#  'Artificial Intelligence, Product Search, SaaS, Service Industry, Software',
#  'Internet of Things, Waste Management',
#  'Air Transportation, Freight Service, Logistics, Marine Transportation',
#  'Financial Services',
# ...

# %%
# Filter the data where the "Sector" column is equal to "Manchester, Greater Manchester"
data_df[data_df['Sector'] == "Manchester, Greater Manchester"]
# Out:
#      Company_Brand                          Sector     Stage      Amount  \
# 2834          Peak  Manchester, Greater Manchester  Series C  75000000.0
#
#                             HeadQuarter  \
# 2834  Information Technology & Services
#
#                                            What it does  Year  Founded  \
# 2834  Peak helps the world's smartest companies put ...  2021   2014.0
#
#          Founders                Investor
# 2834  Atul Sharma  SoftBank Vision Fund 2

# %%
# Swap values between 'Sector' and 'HeadQuarter' columns for the row where 'Company_Brand' is 'Peak'
data_df.loc[data_df['Company_Brand'] == 'Peak', ['Sector', 'HeadQuarter']] = data_df.loc[data_df['Company_Brand'] == 'Peak', ['HeadQuarter', 'Sector']].values

# Filter the data where the "Company_Brand" column is equal to Peak
data_df[data_df['Company_Brand'] == "Peak"]
# Out:
#      Company_Brand                             Sector     Stage      Amount  \
# 2834          Peak  Information Technology & Services  Series C  75000000.0
#
#                          HeadQuarter  \
# 2834  Manchester, Greater Manchester
#
#                                            What it does  Year  Founded  \
# 2834  Peak helps the world's smartest companies put ...  2021   2014.0
#
#          Founders                Investor
# 2834  Atul Sharma  SoftBank Vision Fund 2

# %%
# Get unique values in the Company_Brand column
unique_sectors = data_df['Sector'].unique()

# Convert the unique values array to a list
unique_sectors_list = unique_sectors.tolist()

# Print the list of unique company brands
unique_sectors_list
# Out:
# ['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing',
#  'Agriculture, Farming',
#  'Credit, Financial Services, Lending, Marketplace',
#  'Financial Services, FinTech',
#  'E-Commerce Platforms, Retail, SaaS',
#  'Cloud Infrastructure, PaaS, SaaS',
#  'Internet, Leisure, Marketplace',
#  'Market Research',
#  'Information Services, Information Technology',
#  'Mobile Payments',
#  'B2B, Shoes',
#  'Internet',
#  'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat',
#  'Food Delivery',
#  'Industrial Automation',
#  'Automotive, Search Engine, Service Industry',
#  'Finance, Internet, Travel',
#  'Accounting, Business Information Systems, Business Travel, Finance, SaaS',
#  'Artificial Intelligence, Product Search, SaaS, Service Industry, Software',
#  'Internet of Things, Waste Management',
#  'Air Transportation, Freight Service, Logistics, Marine Transportation',
#  'Financial Services',
# ...

# %% [markdown]
# #### Mapping sectors

# %%
backup_before_mapping=data_df

# %%
data_df= backup_before_mapping

# %%
# Read the CSV file into a DataFrame
sector_map_df = pd.read_csv('../analysis-into-indian-startup-ecosystem/dataset/sector_map.csv')

# %%
sector_map_df['Main Sector'].unique()
# Out:
# array(['Manufacturing', 'Marketing & Communication', 'Media Technology',
#        'Sports & Fitness', 'Technology', 'Transport & Logistics',
#        'Transportation', 'Travel, Tourism & Hospitality', 'Adtech',
#        'Aerospace', 'Agribusiness', 'Agriculture', 'Agritech', 'AI',
#        'Biotech', 'Building and real estate', 'Business',
#        'Business & Technology', 'Consultation', 'E-Business',
#        'E-Commerce', 'Edtech', 'Education', 'Energy', 'Energytech',
#        'Entertainment', 'Events', 'Fashion & Lifestyle', 'Finance',
#        'finance', 'Fintech', 'Food', 'food', 'Gaming & eSports',
#        'Government', 'Health Care', 'Health Care & Wellness',
#        'Health care & Wellness', 'Healthtech', 'ICT', nan], dtype=object)

# %%
sector_map_df.columns
# Out:
# Index(['Sector', 'Main Sector', 'industry'], dtype='object')

# %%
data_df.columns
# Out:
# Index(['Company_Brand', 'Sector', 'Stage', 'Amount', 'HeadQuarter',
#        'What it does', 'Year', 'Founded', 'Founders', 'Investor'],
#       dtype='object')

# %%
# Iterate over the 'Sector' column of data_df
for sector in data_df['Sector']:
    # Check if the sector exists in sector_map_df
    if sector in sector_map_df['Sector'].values:
        # Find the corresponding row in sector_map_df
        sector_row = sector_map_df[sector_map_df['Sector'] == sector]
        # Get the 'Main Sector' and 'industry' values
        main_sector = sector_row['Main Sector'].values[0]
        industry = sector_row['industry'].values[0]
        # Update the corresponding rows in data_df
        data_df.loc[data_df['Sector'] == sector, 'Main Sector'] = main_sector
        data_df.loc[data_df['Sector'] == sector, 'industry'] = industry

# %%
data_df.head(20)
# Out:
#                        Company_Brand  \
# 0                    TheCollegeFever
# 1                    Happy Cow Dairy
# 2                         MyLoanCare
# 3                        PayMe India
# 4                           Eunimart
# 5                             Hasura
# 6                          Tripshelf
# 7                       Hyperdata.IO
# 8                       Freightwalla
# 9                 Microchip Payments
# 10        BizCrum Infotech Pvt. Ltd.
# 11                           Emojifi
# 12                             Flock
# 13                         Freshboxx
# 14        Wide Mobility Mechatronics
# 15                           Pitstop
# 16                            Mihuru
# 17                              Fyle
# 18                          AppWharf
# 19  Antariksh Waste Ventures Pvt ltd
#
#                                                Sector     Stage     Amount  \
# 0   Brand Marketing, Event Promotion, Marketing, S...      Seed   250000.0
# ...

# %%
data_df.tail(50)
# Out:
#                Company_Brand                             Sector  \
# 2813  Boutique Spirit Brands                     Wine & Spirits
# 2814                  eShipz                       SaaS startup
# 2815               Pine Labs  Information Technology & Services
# 2816                 Paytail                 Financial Services
# 2817                    4Fin                 Financial Services
# 2820              immunitoAI                      Biotechnology
# 2821         GameEon Studios                     Computer Games
# 2822      Farmers Fresh Zone                           AgriTech
# 2823                Anveshan                    Food Production
# 2825                Coutloot                  Consumer Services
# 2826           Nova Benefits         Health, Wellness & Fitness
# 2827                HomeLane                    Interior Design
# 2828           Lido Learning                         E-learning
# 2829                     Jar                            FinTech
# ...

# %%
# Reorder the columns in merged_df
data_df = data_df[['Company_Brand', 'Sector', 'Main Sector', 'industry', 'Stage', 'Amount', 'HeadQuarter', 'What it does', 'Year', 'Founded', 'Founders', 'Investor']]

# Display the reordered DataFrame
data_df.head()
# Out:
#      Company_Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#                  Main Sector     industry     Stage     Amount HeadQuarter  \
# 0  Marketing & Communication     business      Seed   250000.0   Bangalore
# 1               Agribusiness  agriculture      Seed   584000.0      Mumbai
# 2                    Finance      finance  Series A   949000.0     Gurgaon
# 3                    Fintech      finance     Angel  2000000.0       Noida
# 4                 E-Commerce     business      Seed        NaN   Hyderabad
#
#                                         What it does  Year  Founded Founders  \
# ...

# %%
# Filter rows where either 'Main Sector' or 'industry' has missing values
data_df[data_df['Main Sector'].isnull() | data_df['industry'].isnull()]
# Out:
#                  Company_Brand                    Sector Main Sector industry  \
# 58    MissMalini Entertainment                         —         NaN      NaN
# 105           Jagaran Microfin                         —         NaN      NaN
# 121                     FLEECA                         —         NaN      NaN
# 146                  WheelsEMI                         —         NaN      NaN
# 153                Fric Bergen                         —         NaN      NaN
# ...                        ...                       ...         ...      ...
# 2860                Voxelgrids                  Deeptech         NaN      NaN
# 2861        Cogos Technologies  Logistics & Supply Chain         NaN      NaN
# 2862                  Gigforce     Staffing & Recruiting         NaN      NaN
# 2863                    Vahdam          Food & Beverages         NaN      NaN
# 2865              CollegeDekho                    EdTech         NaN      NaN
#
# ...

# %%
# Update values where 'Company_Brand' is 'MissMalini Entertainment'
data_df.loc[data_df['Company_Brand'] == 'MissMalini Entertainment', 'Sector'] = 'Media and Entertainment, News, Outdoors'
data_df.loc[data_df['Company_Brand'] == 'MissMalini Entertainment', 'Main Sector'] = 'Entertainment'
data_df.loc[data_df['Company_Brand'] == 'MissMalini Entertainment', 'industry'] = 'Entertainment'

# Display the updated DataFrame
data_df[data_df['Company_Brand'] == 'MissMalini Entertainment']
# Out:
#                Company_Brand                                   Sector  \
# 58  MissMalini Entertainment  Media and Entertainment, News, Outdoors
#
#       Main Sector       industry Stage     Amount HeadQuarter  \
# 58  Entertainment  Entertainment  Seed  1518400.0      Mumbai
#
#                                          What it does  Year  Founded Founders  \
# 58  MissMalini Entertainment is a multi-platform n...  2018      NaN      NaN
#
#    Investor
# 58      NaN

# %%
# Update values where 'Company_Brand' is 'Jagaran Microfin'
data_df.loc[data_df['Company_Brand'] == 'Jagaran Microfin', 'Sector'] = 'Financial Services'
data_df.loc[data_df['Company_Brand'] == 'Jagaran Microfin', 'Main Sector'] = 'Finance'
data_df.loc[data_df['Company_Brand'] == 'Jagaran Microfin', 'industry'] = 'finance'

# Display the updated DataFrame
data_df[data_df['Company_Brand'] == 'Jagaran Microfin']
# Out:
#         Company_Brand              Sector Main Sector industry  \
# 105  Jagaran Microfin  Financial Services     Finance  finance
#
#               Stage     Amount HeadQuarter  \
# 105  Debt Financing  8030000.0     Kolkata
#
#                                           What it does  Year  Founded  \
# 105  Jagaran Microfin is a Microfinance institution...  2018      NaN
#
#     Founders Investor
# 105      NaN      NaN

# %%
# Define the conditions for updating
condition = (data_df['Company_Brand'] == 'FLEECA') | (data_df['Company_Brand'] == 'WheelsEMI')

# Update values based on the conditions
data_df.loc[condition, 'Sector'] = 'Manufacturing'
data_df.loc[condition, 'Main Sector'] = 'Manufacturing'
data_df.loc[condition, 'industry'] = 'manufacturing'

# Display the updated DataFrame
data_df[condition]
# Out:
#     Company_Brand         Sector    Main Sector       industry     Stage  \
# 121        FLEECA  Manufacturing  Manufacturing  manufacturing      Seed
# 146     WheelsEMI  Manufacturing  Manufacturing  manufacturing  Series B
#
#          Amount HeadQuarter  \
# 121         NaN      Jaipur
# 146  14000000.0        Pune
#
#                                           What it does  Year  Founded  \
# 121            FLEECA is a Tyre Care Provider company.  2018      NaN
# 146  WheelsEMI is the brand name of NBFC, WheelsEMI...  2018      NaN
#
#     Founders Investor
# 121      NaN      NaN
# 146      NaN      NaN

# %%
# Update values where 'Company_Brand' is 'Fric Bergen' or 'dishq'
data_df.loc[data_df['Company_Brand'] == 'Fric Bergen', 'Sector'] = 'Food'
data_df.loc[data_df['Company_Brand'] == 'Fric Bergen', 'Main Sector'] = 'food'
data_df.loc[data_df['Company_Brand'] == 'Fric Bergen', 'industry'] = 'food'

data_df.loc[data_df['Company_Brand'] == 'dishq', 'Sector'] = 'Food'
data_df.loc[data_df['Company_Brand'] == 'dishq', 'Main Sector'] = 'food'
data_df.loc[data_df['Company_Brand'] == 'dishq', 'industry'] = 'food'

# Display the updated DataFrame
data_df[(data_df['Company_Brand'] == 'Fric Bergen') | (data_df['Company_Brand'] == 'dishq')]
# Out:
#     Company_Brand Sector Main Sector industry                     Stage  \
# 153   Fric Bergen   Food        food     food  Venture - Series Unknown
# 235         dishq   Food        food     food                      Seed
#
#        Amount HeadQuarter                                       What it does  \
# 153       NaN       Alwar  Fric Bergen is a leader in the specialty food ...
# 235  400000.0   Bengaluru  dishq leverages food science and machine learn...
#
#      Year  Founded Founders Investor
# 153  2018      NaN      NaN      NaN
# 235  2018      NaN      NaN      NaN

# %%
# Update values where 'Company_Brand' is 'Deftouch'
data_df.loc[data_df['Company_Brand'] == 'Deftouch', 'Sector'] = 'Gaming, iOS, Sports'
data_df.loc[data_df['Company_Brand'] == 'Deftouch', 'Main Sector'] = 'Gaming & eSports'
data_df.loc[data_df['Company_Brand'] == 'Deftouch', 'industry'] = 'Gaming & eSports'

# Display the updated DataFrame
data_df[data_df['Company_Brand'] == 'Deftouch']
# Out:
#     Company_Brand               Sector       Main Sector          industry  \
# 174      Deftouch  Gaming, iOS, Sports  Gaming & eSports  Gaming & eSports
#
#     Stage  Amount HeadQuarter  \
# 174  Seed     NaN   Bangalore
#
#                                           What it does  Year  Founded  \
# 174  Deftouch is a mobile game development company ...  2018      NaN
#
#     Founders Investor
# 174      NaN      NaN

# %%
# Update values where 'Company_Brand' is 'Corefactors'
data_df.loc[data_df['Company_Brand'] == 'Corefactors', 'Sector'] = 'Events'
data_df.loc[data_df['Company_Brand'] == 'Corefactors', 'Main Sector'] = 'Events'
data_df.loc[data_df['Company_Brand'] == 'Corefactors', 'industry'] = 'business'

# Display the updated DataFrame
data_df[data_df['Company_Brand'] == 'Corefactors']
# Out:
#     Company_Brand  Sector Main Sector  industry Stage  Amount HeadQuarter  \
# 181   Corefactors  Events      Events  business  Seed     NaN   Bangalore
#
#                                           What it does  Year  Founded  \
# 181  Corefactors is a leading campaign management, ...  2018      NaN
#
#     Founders Investor
# 181      NaN      NaN

# %%
# Define the values to update
update_values = {
    'Sector': 'Technology',
    'Main Sector': 'Technology',
    'industry': 'technology'
}

# Update values where 'Company_Brand' is 'Toddle' or 'HaikuJAM'
data_df.loc[data_df['Company_Brand'] == 'Toddle', ['Sector', 'Main Sector', 'industry']] = update_values.values()
data_df.loc[data_df['Company_Brand'] == 'HaikuJAM', ['Sector', 'Main Sector', 'industry']] = update_values.values()

# Display the updated DataFrame
data_df[data_df['Company_Brand'].isin(['Toddle', 'HaikuJAM'])]
# Out:
#      Company_Brand      Sector Main Sector    industry Stage     Amount  \
# 1615        Toddle  Technology  Technology  technology  None        NaN
# 1634      HaikuJAM  Technology  Technology  technology  None  3400000.0
#
#      HeadQuarter                                       What it does  Year  \
# 1615   Bengaluru  Collaboration and productivity platform for te...  2020
# 1634        None                   Creative writing mobile platform  2020
#
#       Founded                        Founders  \
# 1615      NaN  Deepanshu Arora, Parita Parekh
# 1634      NaN                     Neer Sharma
#
#                                      Investor
# 1615                    Matrix Partners India
# 1634  Lightbox. Social Capital, Dunce Capital

# %%
# Update values where 'Company_Brand' is 'Cell Propulsion' or 'Steradian Semiconductors'
data_df.loc[data_df['Company_Brand'] == 'Cell Propulsion', 'Sector'] = 'Manufacturing'
data_df.loc[data_df['Company_Brand'] == 'Cell Propulsion', 'Main Sector'] = 'Manufacturing'
data_df.loc[data_df['Company_Brand'] == 'Cell Propulsion', 'industry'] = 'manufacturing'

data_df.loc[data_df['Company_Brand'] == 'Steradian Semiconductors', 'Sector'] = 'Manufacturing'
data_df.loc[data_df['Company_Brand'] == 'Steradian Semiconductors', 'Main Sector'] = 'Manufacturing'
data_df.loc[data_df['Company_Brand'] == 'Steradian Semiconductors', 'industry'] = 'manufacturing'

# Display the updated DataFrame for 'Cell Propulsion'
print(data_df[data_df['Company_Brand'] == 'Cell Propulsion'])

# Display the updated DataFrame for 'Steradian Semiconductors'
data_df[data_df['Company_Brand'] == 'Steradian Semiconductors']
# Out:
#         Company_Brand         Sector    Main Sector       industry  \
# 210   Cell Propulsion  Manufacturing  Manufacturing  manufacturing
# 1051  Cell Propulsion  Manufacturing  Manufacturing  manufacturing
# 2289  Cell Propulsion  Manufacturing  Manufacturing  manufacturing
#
#              Stage     Amount HeadQuarter  \
# 210           Seed   102200.0   Bangalore
# 1051  Pre-series A        NaN   Bangalore
# 2289          None  2000000.0   Bangalore
#
#                                            What it does  Year  Founded  \
# 210   Cell Propulsion is an electric mobility startu...  2018      NaN
# 1051  Designs and develops electric power drives and...  2020   2017.0
# 2289  Cell Propulsion is a fleet electrification com...  2021   2016.0
#
#                                          Founders  \
# 210                                           NaN
# 1051  Nakul Kukar, Paras Kaushal, Supratim Naskar
# 2289                   Nakul Kukar, Paras Kaushal
#
# ...

# %%
# Update values for Company_Brand equal to 'Flathalt'
data_df.loc[data_df['Company_Brand'] == 'Flathalt', 'Sector'] = 'Building and real estate'
data_df.loc[data_df['Company_Brand'] == 'Flathalt', 'Main Sector'] = 'Building and real estate'
data_df.loc[data_df['Company_Brand'] == 'Flathalt', 'industry'] = 'building & real estate'

# Update values for Company_Brand equal to 'HousingMan.com'
data_df.loc[data_df['Company_Brand'] == 'HousingMan.com', 'Sector'] = 'Building and real estate'
data_df.loc[data_df['Company_Brand'] == 'HousingMan.com', 'Main Sector'] = 'Building and real estate'
data_df.loc[data_df['Company_Brand'] == 'HousingMan.com', 'industry'] = 'building & real estate'

# Update values for Company_Brand equal to 'Brick&Bolt'
data_df.loc[data_df['Company_Brand'] == 'Brick&Bolt', 'Sector'] = 'Building and real estate'
data_df.loc[data_df['Company_Brand'] == 'Brick&Bolt', 'Main Sector'] = 'Building and real estate'
data_df.loc[data_df['Company_Brand'] == 'Brick&Bolt', 'industry'] = 'building & real estate'

# Display the updated DataFrame
data_df[(data_df['Company_Brand'] == 'Flathalt') | (data_df['Company_Brand'] == 'HousingMan.com') | (data_df['Company_Brand'] == 'Brick&Bolt')]
# Out:
#        Company_Brand                    Sector               Main Sector  \
# 230         Flathalt  Building and real estate  Building and real estate
# 242   HousingMan.com  Building and real estate  Building and real estate
# 1087      Brick&Bolt  Building and real estate  Building and real estate
# 1529      Brick&Bolt  Building and real estate  Building and real estate
#
#                     industry         Stage     Amount HeadQuarter  \
# 230   building & real estate         Angel    50000.0     Gurgaon
# 242   building & real estate          Seed  1503800.0   Bengaluru
# 1087  building & real estate      Series A  2200000.0   Bangalore
# 1529  building & real estate  Pre series A  1500000.0   Bangalore
#
#                                            What it does  Year  Founded  \
# 230                     FInd your Customized Home here.  2018      NaN
# 242         New Apartments, Flats for Sale in Bangalore  2018      NaN
# ...

# %%
# Update values for Trell
data_df.loc[data_df['Company_Brand'] == 'Trell', ['Sector', 'Main Sector', 'industry']] = ['Technology', 'Technology', 'technology']

# Update values for Sequretek
data_df.loc[data_df['Company_Brand'] == 'Sequretek', ['Sector', 'Main Sector', 'industry']] = ['Technology', 'Technology', 'technology']

# Update values for Servify
data_df.loc[data_df['Company_Brand'] == 'Servify', ['Sector', 'Main Sector', 'industry']] = ['Technology', 'Technology', 'technology']

# Display the updated DataFrame for the specified Company_Brands
selected_company_brands = ['Trell', 'Sequretek', 'Servify']
data_df[data_df['Company_Brand'].isin(selected_company_brands)]
# Out:
#      Company_Brand      Sector Main Sector    industry  \
# 238          Trell  Technology  Technology  technology
# 472      Sequretek  Technology  Technology  technology
# 559          Trell  Technology  Technology  technology
# 1005       Servify  Technology  Technology  technology
# 1028       Servify  Technology  Technology  technology
# 1106         Trell  Technology  Technology  technology
# 1247       Servify  Technology  Technology  technology
# 1335       Servify  Technology  Technology  technology
# 1470         Trell  Technology  Technology  technology
# 2197         Trell  Technology  Technology  technology
# 2684         Trell  Technology  Technology  technology
#
#                          Stage       Amount     HeadQuarter  \
# 238                       Seed    1250000.0  Bangalore City
# 472   Venture - Series Unknown    3700000.0          Mumbai
# 559               Pre series A    2000000.0       Bangalore
# ...

# %%
# Update values where 'Company_Brand' is 'SaffronStays'
data_df.loc[data_df['Company_Brand'] == 'SaffronStays', 'Sector'] = 'Travel'
data_df.loc[data_df['Company_Brand'] == 'SaffronStays', 'Main Sector'] = 'Travel, Tourism & Hospitality'
data_df.loc[data_df['Company_Brand'] == 'SaffronStays', 'industry'] = 'hospitality'

# Display the updated DataFrame
data_df[data_df['Company_Brand'] == 'SaffronStays']
# Out:
#     Company_Brand  Sector                    Main Sector     industry Stage  \
# 247  SaffronStays  Travel  Travel, Tourism & Hospitality  hospitality  Seed
#
#         Amount HeadQuarter                                       What it does  \
# 247  2000000.0      Mumbai  SaffronStays connects travellers to India's In...
#
#      Year  Founded Founders Investor
# 247  2018      NaN      NaN      NaN

# %%
# Update values where 'Company_Brand' is 'Inner Being Wellness' or 'Iba Halal Care'
data_df.loc[data_df['Company_Brand'] == 'Inner Being Wellness', 'Sector'] = 'Health Care'
data_df.loc[data_df['Company_Brand'] == 'Inner Being Wellness', 'Main Sector'] = 'Health Care & Wellness'
data_df.loc[data_df['Company_Brand'] == 'Inner Being Wellness', 'industry'] = 'health'

data_df.loc[data_df['Company_Brand'] == 'Iba Halal Care', 'Sector'] = 'Health Care'
data_df.loc[data_df['Company_Brand'] == 'Iba Halal Care', 'Main Sector'] = 'Health Care & Wellness'
data_df.loc[data_df['Company_Brand'] == 'Iba Halal Care', 'industry'] = 'health'

# Display the updated DataFrame
data_df[(data_df['Company_Brand'] == 'Inner Being Wellness') | (data_df['Company_Brand'] == 'Iba Halal Care')]
# Out:
#             Company_Brand       Sector             Main Sector industry  \
# 251  Inner Being Wellness  Health Care  Health Care & Wellness   health
# 478        Iba Halal Care  Health Care  Health Care & Wellness   health
#
#         Stage     Amount HeadQuarter  \
# 251     Angel   511000.0   Hyderabad
# 478  Series A  2190000.0   Ahmedabad
#
#                                           What it does  Year  Founded  \
# 251  Inner Being Wellness manufactures beauty, well...  2018      NaN
# 478       Iba Halal Care is a cosmetics brand company.  2018      NaN
#
#     Founders Investor
# 251      NaN      NaN
# 478      NaN      NaN

# %%
# Update values where 'Sector' is '—'
data_df.loc[data_df['Sector'] == '—', 'Sector'] = 'Others'
data_df.loc[data_df['Sector'] == '—', 'Main Sector'] = 'Others'
data_df.loc[data_df['Sector'] == '—', 'industry'] = 'Others'

# Display the updated DataFrame
data_df[data_df['Sector'] == 'Others']
# Out:
#                                      Company_Brand  Sector Main Sector  \
# 257                                       MySEODoc  Others         NaN
# 258       ENLYFT DIGITAL SOLUTIONS PRIVATE LIMITED  Others         NaN
# 259                                     Scale Labs  Others         NaN
# 294                                       Roadcast  Others         NaN
# 325                                         Toffee  Others         NaN
# 326                                     ORO Wealth  Others         NaN
# 346                                        Finwego  Others         NaN
# 398                                           Cred  Others         NaN
# 457                                          Origo  Others         NaN
# 473               Avenues Payments India Pvt. Ltd.  Others         NaN
# 476  Planet11 eCommerce Solutions India (Avenue11)  Others         NaN
# 480                                         Togedr  Others         NaN
# ...

# %%
# Update values where 'Sector' is 'Others'
data_df.loc[data_df['Sector'] == 'Others', 'Sector'] = 'Others'
data_df.loc[data_df['Sector'] == 'Others', 'Main Sector'] = 'others'
data_df.loc[data_df['Sector'] == 'Others', 'industry'] = 'others'

# Display the updated DataFrame
data_df[data_df['Sector'] == 'Others']
# Out:
#                                      Company_Brand  Sector Main Sector  \
# 257                                       MySEODoc  Others      others
# 258       ENLYFT DIGITAL SOLUTIONS PRIVATE LIMITED  Others      others
# 259                                     Scale Labs  Others      others
# 294                                       Roadcast  Others      others
# 325                                         Toffee  Others      others
# 326                                     ORO Wealth  Others      others
# 346                                        Finwego  Others      others
# 398                                           Cred  Others      others
# 457                                          Origo  Others      others
# 473               Avenues Payments India Pvt. Ltd.  Others      others
# 476  Planet11 eCommerce Solutions India (Avenue11)  Others      others
# 480                                         Togedr  Others      others
# ...

# %%
# Update values where 'Sector' is NaN
data_df.loc[data_df['Sector'].isnull(), 'Sector'] = 'Others'
data_df.loc[data_df['Sector'].isnull(), 'Main Sector'] = 'others'
data_df.loc[data_df['Sector'].isnull(), 'industry'] = 'others'

# Display the updated DataFrame
data_df[data_df['Sector'] .isnull()]
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Main Sector, industry, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
data_df.head(15)
# Out:
#                  Company_Brand  \
# 0              TheCollegeFever
# 1              Happy Cow Dairy
# 2                   MyLoanCare
# 3                  PayMe India
# 4                     Eunimart
# 5                       Hasura
# 6                    Tripshelf
# 7                 Hyperdata.IO
# 8                 Freightwalla
# 9           Microchip Payments
# 10  BizCrum Infotech Pvt. Ltd.
# 11                     Emojifi
# 12                       Flock
# 13                   Freshboxx
# 14  Wide Mobility Mechatronics
#
#                                                Sector  \
# 0   Brand Marketing, Event Promotion, Marketing, S...
# 1                                Agriculture, Farming
# 2    Credit, Financial Services, Lending, Marketplace
# 3                         Financial Services, FinTech
# 4                  E-Commerce Platforms, Retail, SaaS
# 5                    Cloud Infrastructure, PaaS, SaaS
# 6                      Internet, Leisure, Marketplace
# ...

# %%
# Export the DataFrame to a CSV file
data_df.to_csv('./dataset/data_processed.csv', index=False)

# %%
# Read the CSV file into a DataFrame
data_processed = pd.read_csv('./dataset/data_processed.csv')
data_processed.head()
# Out:
#      Company_Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#                  Main Sector     industry     Stage     Amount HeadQuarter  \
# 0  Marketing & Communication     business      Seed   250000.0   Bangalore
# 1               Agribusiness  agriculture      Seed   584000.0      Mumbai
# 2                    Finance      finance  Series A   949000.0     Gurgaon
# 3                    Fintech      finance     Angel  2000000.0       Noida
# 4                 E-Commerce     business      Seed        NaN   Hyderabad
#
#                                         What it does  Year  Founded Founders  \
# ...

# %%
data_processed_df=data_processed

# %%
# Display the updated DataFrame
data_processed_df.head(25)
# Out:
#                        Company_Brand  \
# 0                    TheCollegeFever
# 1                    Happy Cow Dairy
# 2                         MyLoanCare
# 3                        PayMe India
# 4                           Eunimart
# 5                             Hasura
# 6                          Tripshelf
# 7                       Hyperdata.IO
# 8                       Freightwalla
# 9                 Microchip Payments
# 10        BizCrum Infotech Pvt. Ltd.
# 11                           Emojifi
# 12                             Flock
# 13                         Freshboxx
# 14        Wide Mobility Mechatronics
# 15                           Pitstop
# 16                            Mihuru
# 17                              Fyle
# 18                          AppWharf
# 19  Antariksh Waste Ventures Pvt ltd
# 20                          Cogoport
# 21                        PaisaDukan
# 22                 Sleepy Owl Coffee
# 23                          BlueJack
# ...

# %%
data_df= data_processed_df

# %%
# Convert values to sentence case for 'Sector', 'Main Sector', and 'industry' columns
data_df['Sector'] = data_df['Sector'].str.title()
data_df['Main Sector'] = data_df['Main Sector'].str.title()
data_df['industry'] = data_df['industry'].str.title()

# Display the updated DataFrame
data_df.head(15)
# Out:
#                  Company_Brand  \
# 0              TheCollegeFever
# 1              Happy Cow Dairy
# 2                   MyLoanCare
# 3                  PayMe India
# 4                     Eunimart
# 5                       Hasura
# 6                    Tripshelf
# 7                 Hyperdata.IO
# 8                 Freightwalla
# 9           Microchip Payments
# 10  BizCrum Infotech Pvt. Ltd.
# 11                     Emojifi
# 12                       Flock
# 13                   Freshboxx
# 14  Wide Mobility Mechatronics
#
#                                                Sector  \
# 0   Brand Marketing, Event Promotion, Marketing, S...
# 1                                Agriculture, Farming
# 2    Credit, Financial Services, Lending, Marketplace
# 3                         Financial Services, Fintech
# 4                  E-Commerce Platforms, Retail, Saas
# 5                    Cloud Infrastructure, Paas, Saas
# 6                      Internet, Leisure, Marketplace
# ...

# %% [markdown]
# ### Cleaning the Stage Column

# %%
# Get unique values in the Stage column
unique_stages = data_df['Stage'].unique()

# Convert the unique values array to a list``
unique_stages_list = unique_stages.tolist()

# Print the list of unique stages
unique_stages_list
# Out:
# ['Seed',
#  'Series A',
#  'Angel',
#  'Series B',
#  'Pre-Seed',
#  'Private Equity',
#  'Venture - Series Unknown',
#  'Grant',
#  'Debt Financing',
#  'Post-IPO Debt',
#  'Series H',
#  'Series C',
#  'Series E',
#  'Corporate Round',
#  'Undisclosed',
#  'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',
#  'Series D',
#  'Secondary Market',
#  'Post-IPO Equity',
#  'Non-equity Assistance',
#  'Funding Round',
#  nan,
#  'Fresh funding',
#  'Pre series A',
#  'Series G',
#  'Post series A',
#  'Seed funding',
#  'Seed fund',
#  'Series F',
#  'Series B+',
#  'Seed round',
#  'Pre-series A',
#  'Pre-seed',
#  'Pre-series',
#  'Debt',
#  'Pre-series C',
#  'Pre-series B',
#  'Bridge',
#  'Series B2',
#  'Pre- series A',
#  'Edge',
#  'Pre-Series B',
#  'Seed A',
#  'Series A-1',
#  'Seed Funding',
#  'Pre-seed Round',
#  'Seed Round & Series A',
#  'Pre Series A',
#  'Pre seed Round',
#  'Angel Round',
#  'Pre series A1',
# ...

# %%
data_df[data_df['Stage'] == 'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593']
# Out:
#       Company_Brand  Sector                    Main Sector     industry  \
# 178  BuyForexOnline  Travel  Travel, Tourism & Hospitality  Hospitality
#
#                                                  Stage     Amount HeadQuarter  \
# 178  https://docs.google.com/spreadsheets/d/1x9ziNe...  2000000.0   Bangalore
#
#                                           What it does  Year  Founded  \
# 178  BuyForexOnline.com is India's first completely...  2018      NaN
#
#     Founders Investor
# 178      NaN      NaN

# %%
# Set the values in the 'Stage' column to an empty string where the value is equal to the specified URL
data_df.loc[data_df['Stage'] == 'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593', 'Stage'] = ''
data_df[data_df['Company_Brand'] == 'BuyForexOnline']
# Out:
#       Company_Brand  Sector                    Main Sector     industry Stage  \
# 178  BuyForexOnline  Travel  Travel, Tourism & Hospitality  Hospitality
#
#         Amount HeadQuarter                                       What it does  \
# 178  2000000.0   Bangalore  BuyForexOnline.com is India's first completely...
#
#      Year  Founded Founders Investor
# 178  2018      NaN      NaN      NaN

# %%
# Set the 'Stage' column to an empty string where the value is equal to '$6000000'
data_df.loc[data_df['Stage'] == '$6000000', 'Stage'] = ''
data_df[data_df['Company_Brand'] == 'MYRE Capital']
# Out:
#      Company_Brand                  Sector Main Sector industry Stage  Amount  \
# 2239  MYRE Capital  Commercial Real Estate         NaN      NaN           NaN
#
#      HeadQuarter                         What it does  Year  Founded  \
# 2239      Mumbai  Democratising Real Estate Ownership  2021   2020.0
#
#                                      Founders     Investor
# 2239  Own rent yielding commercial properties  Aryaman Vir

# %%
# Set 'Amount' to 60000000 for the row where 'Company_Brand' is 'MYRE Capital'
data_df.loc[data_df['Company_Brand'] == 'MYRE Capital', 'Amount'] = 60000000
data_df[data_df['Company_Brand'] == 'MYRE Capital']
# Out:
#      Company_Brand                  Sector Main Sector industry Stage  \
# 2239  MYRE Capital  Commercial Real Estate         NaN      NaN
#
#           Amount HeadQuarter                         What it does  Year  \
# 2239  60000000.0      Mumbai  Democratising Real Estate Ownership  2021
#
#       Founded                                 Founders     Investor
# 2239   2020.0  Own rent yielding commercial properties  Aryaman Vir

# %%
# Select rows where the 'Stage' column contains NaN values
data_df[pd.isna(data_df['Stage'])]
# Out:
#        Company_Brand                 Sector Main Sector     industry Stage  \
# 526   Bombay Shaving              Ecommerce  E-Commerce     Business   NaN
# 530         Nu Genes               Agritech    Agritech  Agriculture   NaN
# 534         Appnomic                   Saas  Technology   Technology   NaN
# 536        JobSquare                Hr Tech  Technology   Technology   NaN
# 537           LivFin                Fintech     Fintech      Finance   NaN
# ...              ...                    ...         ...          ...   ...
# 2683   Lido Learning             E-Learning         NaN          NaN   NaN
# 2685      Peppermint  Industrial Automation  Technology   Technology   NaN
# 2695       Sugar.fit                 Health         NaN          NaN   NaN
# 2705       Geniemode                    B2B         NaN          NaN   NaN
# 2714      Voxelgrids               Deeptech         NaN          NaN   NaN
#
#           Amount HeadQuarter  \
# 526    6300000.0         NaN
# ...

# %%
# Convert NaN values in the 'Stage' column to an empty string ('')
data_df.loc[pd.isna(data_df['Stage']), 'Stage'] = ''

# %%
# Get unique values in the Stage column
unique_stages = data_df['Stage'].unique()

# Convert the unique values array to a list``
unique_stages_list = unique_stages.tolist()

# Print the list of unique stages
unique_stages_list
# Out:
# ['Seed',
#  'Series A',
#  'Angel',
#  'Series B',
#  'Pre-Seed',
#  'Private Equity',
#  'Venture - Series Unknown',
#  'Grant',
#  'Debt Financing',
#  'Post-IPO Debt',
#  'Series H',
#  'Series C',
#  'Series E',
#  'Corporate Round',
#  'Undisclosed',
#  '',
#  'Series D',
#  'Secondary Market',
#  'Post-IPO Equity',
#  'Non-equity Assistance',
#  'Funding Round',
#  'Fresh funding',
#  'Pre series A',
#  'Series G',
#  'Post series A',
#  'Seed funding',
#  'Seed fund',
#  'Series F',
#  'Series B+',
#  'Seed round',
#  'Pre-series A',
#  'Pre-seed',
#  'Pre-series',
#  'Debt',
#  'Pre-series C',
#  'Pre-series B',
#  'Bridge',
#  'Series B2',
#  'Pre- series A',
#  'Edge',
#  'Pre-Series B',
#  'Seed A',
#  'Series A-1',
#  'Seed Funding',
#  'Pre-seed Round',
#  'Seed Round & Series A',
#  'Pre Series A',
#  'Pre seed Round',
#  'Angel Round',
#  'Pre series A1',
#  'Series E2',
#  'Seed Round',
#  'Bridge Round',
#  'Pre seed round',
#  'Pre series B',
#  'Pre series C',
# ...

# %% [markdown]
# ### Cleaning HeadQuarter Column

# %%
# Get unique values in the HeadQuarter column
unique_HeadQuarter = data_df['HeadQuarter'].unique()

# Convert the unique values array to a list``
unique_HeadQuarter_list = unique_HeadQuarter.tolist()

# Print the list of unique HeadQuarter
unique_HeadQuarter_list
# Out:
# ['Bangalore',
#  'Mumbai',
#  'Gurgaon',
#  'Noida',
#  'Hyderabad',
#  'Bengaluru',
#  'Kalkaji',
#  'Delhi',
#  'India',
#  'Hubli',
#  'New Delhi',
#  'Chennai',
#  'Mohali',
#  'Kolkata',
#  'Pune',
#  'Jodhpur',
#  'Kanpur',
#  'Ahmedabad',
#  'Azadpur',
#  'Haryana',
#  'Cochin',
#  'Faridabad',
#  'Jaipur',
#  'Kota',
#  'Anand',
#  'Bangalore City',
#  'Belgaum',
#  'Thane',
#  'Margão',
#  'Indore',
#  'Alwar',
#  'Kannur',
#  'Trivandrum',
#  'Ernakulam',
#  'Kormangala',
#  'Uttar Pradesh',
#  'Andheri',
#  'Mylapore',
#  'Ghaziabad',
#  'Kochi',
#  'Powai',
#  'Guntur',
#  'Kalpakkam',
#  'Bhopal',
#  'Coimbatore',
#  'Worli',
#  'Alleppey',
#  'Chandigarh',
#  'Guindy',
#  'Lucknow',
#  nan,
#  'Telangana',
#  'Gurugram',
#  'Surat',
#  'Uttar pradesh',
#  'Rajasthan',
#  'Tirunelveli, Tamilnadu',
#  'Singapore',
#  'Gujarat',
#  'Kerala',
#  'Jaipur, Rajastan',
#  'Frisco, Texas, United States',
#  'California',
#  'Dhingsara, Haryana',
#  'New York, United States',
# ...

# %%
# Replace 'Online Media\t#REF!' with 'Online Media'
data_df['HeadQuarter'].replace('Online Media\t#REF!', 'Online Media', inplace=True)

# Replace 'Manchester, Greater Manchester' with 'Manchester'
data_df['HeadQuarter'].replace('Manchester, Greater Manchester', 'Manchester', inplace=True)

# %%
# Get unique values in the HeadQuarter column
unique_HeadQuarter = data_df['HeadQuarter'].unique()

# Convert the unique values array to a list``
unique_HeadQuarter_list = unique_HeadQuarter.tolist()

# Print the list of unique HeadQuarter
unique_HeadQuarter_list
# Out:
# ['Bangalore',
#  'Mumbai',
#  'Gurgaon',
#  'Noida',
#  'Hyderabad',
#  'Bengaluru',
#  'Kalkaji',
#  'Delhi',
#  'India',
#  'Hubli',
#  'New Delhi',
#  'Chennai',
#  'Mohali',
#  'Kolkata',
#  'Pune',
#  'Jodhpur',
#  'Kanpur',
#  'Ahmedabad',
#  'Azadpur',
#  'Haryana',
#  'Cochin',
#  'Faridabad',
#  'Jaipur',
#  'Kota',
#  'Anand',
#  'Bangalore City',
#  'Belgaum',
#  'Thane',
#  'Margão',
#  'Indore',
#  'Alwar',
#  'Kannur',
#  'Trivandrum',
#  'Ernakulam',
#  'Kormangala',
#  'Uttar Pradesh',
#  'Andheri',
#  'Mylapore',
#  'Ghaziabad',
#  'Kochi',
#  'Powai',
#  'Guntur',
#  'Kalpakkam',
#  'Bhopal',
#  'Coimbatore',
#  'Worli',
#  'Alleppey',
#  'Chandigarh',
#  'Guindy',
#  'Lucknow',
#  nan,
#  'Telangana',
#  'Gurugram',
#  'Surat',
#  'Uttar pradesh',
#  'Rajasthan',
#  'Tirunelveli, Tamilnadu',
#  'Singapore',
#  'Gujarat',
#  'Kerala',
#  'Jaipur, Rajastan',
#  'Frisco, Texas, United States',
#  'California',
#  'Dhingsara, Haryana',
#  'New York, United States',
# ...

# %%
# Filter the data where the "HeadQuarter" column is equal to "The Nilgiris"
data_df[data_df['HeadQuarter'] == "The Nilgiris"]
# Out:
#      Company_Brand         Sector Main Sector industry Stage    Amount  \
# 2703       Prolgae  Biotechnology     Biotech  Biotech  Seed  200000.0
#
#        HeadQuarter                                       What it does  Year  \
# 2703  The Nilgiris  Prolgae Spirulina Supplies Pvt. Ltd. is a Nord...  2021
#
#       Founded         Founders Investor
# 2703   2016.0  Aakas Sadasivam  Vijayan

# %% [markdown]
# ### Cleaning what it does column

# %%
# Get unique values in the HeadQuarter column
unique_WiD = data_df['What it does'].unique()

# Convert the unique values array to a list``
unique_WiD_list = unique_WiD.tolist()

# Print the list of unique HeadQuarter
unique_WiD_list
# Out:
# ['TheCollegeFever is a hub for fun, fiesta and frolic of Colleges.',
#  'A startup which aggregates milk from dairy farmers in rural Maharashtra.',
#  'Leading Online Loans Marketplace in India',
#  'PayMe India is an innovative FinTech organization which offers short term financial suport to corporate employees.',
#  'Eunimart is a one stop solution for merchants to create a difference by selling globally.',
#  'Hasura is a platform that allows developers to build, deploy, and host cloud-native applications quickly.',
#  'Tripshelf is an online market place for holiday packages.',
#  'Hyperdata combines advanced machine learning with human intelligence.',
#  'Freightwalla is an international forwarder thats helps you manage supply chain by providing online tools including instant quotations.',
#  'Microchip payments is a mobile-based payment application and point-of-sale device',
#  'Building Transactionary B2B Marketplaces',
# ...

# %% [markdown]
# ### Cleaning the Year Column

# %%
# Get unique values in the Year column
unique_Year = data_df['Year'].unique()

# Convert the unique values array to a list``
unique_Year_list = unique_Year.tolist()

# Print the list of unique Year
unique_Year_list
# Out:
# [2018, 2019, 2020, 2021]

# %% [markdown]
# ###  Cleaning the Founded Column

# %%
# Get unique values in the Founded column
unique_Founded = data_df['Founded'].unique()

# Convert the unique values array to a list``
unique_Founded_list = unique_Founded.tolist()

# Print the list of unique Founded
unique_Founded_list
# Out:
# [nan,
#  2014.0,
#  2004.0,
#  2013.0,
#  2010.0,
#  2018.0,
#  2019.0,
#  2017.0,
#  2011.0,
#  2015.0,
#  2016.0,
#  2012.0,
#  2008.0,
#  2020.0,
#  1998.0,
#  2007.0,
#  1982.0,
#  2009.0,
#  1995.0,
#  2006.0,
#  1978.0,
#  1999.0,
#  1994.0,
#  2005.0,
#  1973.0,
#  2002.0,
#  2001.0,
#  2021.0,
#  1993.0,
#  1989.0,
#  2000.0,
#  2003.0,
#  1991.0,
#  1984.0,
#  1963.0]

# %%
# Filter the data where the "Founded" column contains NaN values
data_df[data_df['Founded'].isna()]
# Out:
#          Company_Brand                                             Sector  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, Fintech
# 4             Eunimart                 E-Commerce Platforms, Retail, Saas
# ...                ...                                                ...
# 1646            Quicko                                           Taxation
# 1647  Satin Creditcare                                            Fintech
# 1653      Leverage Edu                                             Edtech
# 1654             EpiFi                                            Fintech
# 1779     Smart Express                                          Logistics
#
#                     Main Sector     industry       Stage      Amount  \
# ...

# %%
# Calculate the average of non-NaN values in the 'Founded' column
average_founded = data_df['Founded'].mean()

# Fill NaN values in the 'Founded' column with the calculated average
data_df['Founded'].fillna(average_founded, inplace=True)

# Filter the data where the "Founded" column contains NaN values
data_df[data_df['Founded'].isna()]
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Main Sector, industry, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
data_df['Founded'].unique()
# Out:
# array([2015.96053306, 2014.        , 2004.        , 2013.        ,
#        2010.        , 2018.        , 2019.        , 2017.        ,
#        2011.        , 2015.        , 2016.        , 2012.        ,
#        2008.        , 2020.        , 1998.        , 2007.        ,
#        1982.        , 2009.        , 1995.        , 2006.        ,
#        1978.        , 1999.        , 1994.        , 2005.        ,
#        1973.        , 2002.        , 2001.        , 2021.        ,
#        1993.        , 1989.        , 2000.        , 2003.        ,
#        1991.        , 1984.        , 1963.        ])

# %%
# Round all values in the 'Founded' column to the nearest whole number
data_df['Founded'] = data_df['Founded'].round()

# View unique values in the 'Founded' column after rounding
data_df['Founded'].unique()
# Out:
# array([2016., 2014., 2004., 2013., 2010., 2018., 2019., 2017., 2011.,
#        2015., 2012., 2008., 2020., 1998., 2007., 1982., 2009., 1995.,
#        2006., 1978., 1999., 1994., 2005., 1973., 2002., 2001., 2021.,
#        1993., 1989., 2000., 2003., 1991., 1984., 1963.])

# %%
# Convert all values in the 'Founded' column to integers
data_df['Founded'] = data_df['Founded'].astype(int)

# View unique values in the 'Founded' column after conversion
data_df['Founded'].unique()
# Out:
# array([2016, 2014, 2004, 2013, 2010, 2018, 2019, 2017, 2011, 2015, 2012,
#        2008, 2020, 1998, 2007, 1982, 2009, 1995, 2006, 1978, 1999, 1994,
#        2005, 1973, 2002, 2001, 2021, 1993, 1989, 2000, 2003, 1991, 1984,
#        1963])

# %% [markdown]
# ### Cleaning the Founders Coulmn

# %%
# Get unique values in the Founders column
unique_Founders = data_df['Founders'].unique()

# Convert the unique values array to a list``
unique_Founders_list = unique_Founders.tolist()

# Print the list of unique Founded
unique_Founders_list
# Out:
# [nan,
#  'Shantanu Deshpande',
#  'Adamas Belva Syah Devara, Iman Usman.',
#  'Jatin Solanki',
#  'Srikanth Iyer, Rama Harinath',
#  'Narayana Reddy Punyala',
#  'Pavan Kushwaha, Paratosh Bansal, Dip Jung Thapa',
#  'Renuka Ramnath',
#  'Peyush Bansal, Amit Chaudhary, Sumeet Kapahi',
#  'D Padmanabhan',
#  'Puneet Gupta, Sucharita Mukherjee',
#  'Ishit Jethwa',
#  'Rakesh Malhotra',
#  'Byju Raveendran',
#  'Chapman, Priya Sharma, Ashish Anantharaman',
#  'Amit Modi',
#  'Renato Araujo',
#  'Harsimarbir Singh, Dr Vaibhav Kapoor, Dr Garima Sawhney',
#  'Gautam Tambay, Parul Gupta',
#  'Tushar Kumar, Prashant Singh',
#  'Arihant Jain, Ajeet Kushwaha',
#  'Nishant Jain, Rohan Kumar',
#  'Sam Udotong',
#  'Sandipan Mitra, Uttam Kumar',
#  'Nukul Upadhye, Mahesh Jakhotia, Jitender Bedwal, Daya Rai, Nikhil Tripathi',
#  'Vivek Gupta, Abhay Hanjura',
#  'Babu Dayal, Pramod Uniyal, Lalit Mehta',
#  'Neel Mehta, Nihar Vartak',
#  'Deepak Garg, Gazal Kalra',
#  'Vivek Prabhakar, Boris Zha',
# ...

# %% [markdown]
# ### Cleaning the Investor Column

# %%
data_df['Investor'].unique()
# Out:
# array([nan, 'Sixth Sense Ventures', 'General Atlantic', ...,
#        'Owl Ventures', 'Winter Capital, ETS, Man Capital',
#        '3one4 Capital, Kalaari Capital'], dtype=object)

# %% [markdown]
# ###

# %% [markdown]
# ### Checking to see if everything is correct

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2721 entries, 0 to 2720
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2721 non-null   object
#  1   Sector         2721 non-null   object
#  2   Main Sector    1212 non-null   object
#  3   industry       1212 non-null   object
#  4   Stage          2721 non-null   object
#  5   Amount         1970 non-null   float64
#  6   HeadQuarter    2610 non-null   object
#  7   What it does   2721 non-null   object
#  8   Year           2721 non-null   int64
#  9   Founded        2721 non-null   int32
#  10  Founders       2176 non-null   object
#  11  Investor       2101 non-null   object
# dtypes: float64(1), int32(1), int64(1), object(9)
# memory usage: 244.6+ KB

# %%
data_df.head()
# Out:
#      Company_Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, Fintech
# 4         Eunimart                 E-Commerce Platforms, Retail, Saas
#
#                  Main Sector     industry     Stage     Amount HeadQuarter  \
# 0  Marketing & Communication     Business      Seed   250000.0   Bangalore
# 1               Agribusiness  Agriculture      Seed   584000.0      Mumbai
# 2                    Finance      Finance  Series A   949000.0     Gurgaon
# 3                    Fintech      Finance     Angel  2000000.0       Noida
# 4                 E-Commerce     Business      Seed        NaN   Hyderabad
#
#                                         What it does  Year  Founded Founders  \
# ...

# %% [markdown]
# #### the imputation with the mean was chosen to fill the amount column

# %%
# Calculate the mean of non-null values in the 'Amount' column
mean_amount = data_df['Amount'].mean()

# Round the mean to two decimal places
mean_amount_rounded = round(mean_amount, 2)

# Fill missing values in the 'Amount' column with the rounded mean
data_df['Amount'].fillna(mean_amount_rounded, inplace=True)

# %%
data_df['Amount'].min()
# Out:
# 876.0

# %%
data_df[data_df['Amount'] == 0.0]
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Main Sector, industry, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor]
# Index: []

# %%
# Calculate the mean of non-zero amounts
mean_amount = data_df[data_df['Amount'] != 0.0]['Amount'].mean()

# Replace zero values in the 'Amount' column with the mean
data_df.loc[data_df['Amount'] == 0.0, 'Amount'] = mean_amount

# %%
data_df[data_df['Amount'] == 0.0]
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Sector, Main Sector, industry, Stage, Amount, HeadQuarter, What it does, Year, Founded, Founders, Investor, Years of Existence]
# Index: []

# %% [markdown]
# #### REMOVING NON STARTUPS

# %% [markdown]
# According to EU-startups, If we look at the more comprehensive definition of a startup, it cannot just be any ‘fledgling’ business enterprise, it has to be focused on growth and scale. You are no longer a startup if you have achieved scale, albeit the arbitrary the definition of scale. Scale is typically measured in terms of revenue, number of employees and valuation, but can also include age i.e.
# ##### categorizing companies that are more than 5 years old as no longer startups.
# https://www.eu-startups.com/2021/03/when-is-a-startup-no-longer-a-startup/#:~:text=Scale%20is%20typically%20measured%20in,old%20as%20no%20longer%20startups.

# %%
# Calculate the 'Years of Existence' by subtracting 'Founded' from 'Year'
data_df['Years of Existence'] = data_df['Year'] - data_df['Founded']
data_df
# Out:
#         Company_Brand                                             Sector  \
# 0     TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1     Happy Cow Dairy                               Agriculture, Farming
# 2          MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3         PayMe India                        Financial Services, Fintech
# 4            Eunimart                 E-Commerce Platforms, Retail, Saas
# ...               ...                                                ...
# 2716         Gigforce                              Staffing & Recruiting
# 2717           Vahdam                                   Food & Beverages
# 2718     Leap Finance                                 Financial Services
# 2719     CollegeDekho                                             Edtech
# 2720           WeRize                                 Financial Services
#
#                     Main Sector     industry         Stage       Amount  \
# ...

# %%
# Filter data where 'Years of Existence' is greater than 5
years_of_existence_gt_5 = data_df[data_df['Years of Existence'] > 5]
years_of_existence_gt_5
# Out:
#      Company_Brand                    Sector Main Sector     industry  \
# 530       Nu Genes                  Agritech    Agritech  Agriculture
# 531       Kratikal                Technology  Technology   Technology
# 533       Lenskart                E-Commerce         NaN          NaN
# 538         Byju's                    Edtech      Edtech    Education
# 543    Springboard                    Edtech      Edtech    Education
# ...            ...                       ...         ...          ...
# 2707     Delhivery  Logistics & Supply Chain         NaN          NaN
# 2708    Flipspaces                    Design         NaN          NaN
# 2713     TechEagle      Aviation & Aerospace         NaN          NaN
# 2717        Vahdam          Food & Beverages         NaN          NaN
# 2719  CollegeDekho                    Edtech         NaN          NaN
#
#               Stage       Amount HeadQuarter  \
# 530                    6000000.0   Telangana
# ...

# %% [markdown]
# All the above rows will be dropped because at the time of collecting their data, they were more than 5 years which disqualifies them from being startups

# %%
# Drop rows where 'Years of Existence' is greater than 5
data_df = data_df[data_df['Years of Existence'] <= 5]

# Display the updated DataFrame
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2148 entries, 0 to 2720
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company_Brand       2148 non-null   object
#  1   Sector              2148 non-null   object
#  2   Main Sector         1021 non-null   object
#  3   industry            1021 non-null   object
#  4   Stage               2148 non-null   object
#  5   Amount              2148 non-null   float64
#  6   HeadQuarter         2051 non-null   object
#  7   What it does        2148 non-null   object
#  8   Year                2148 non-null   int64
#  9   Founded             2148 non-null   int32
#  10  Founders            1604 non-null   object
#  11  Investor            1544 non-null   object
#  12  Years of Existence  2148 non-null   int64
# dtypes: float64(1), int32(1), int64(2), object(9)
# memory usage: 226.5+ KB

# %%
data_df[data_df['industry'].isnull()]
# Out:
#                                  Company_Brand  \
# 257                                   MySEODoc
# 258   ENLYFT DIGITAL SOLUTIONS PRIVATE LIMITED
# 259                                 Scale Labs
# 294                                   Roadcast
# 325                                     Toffee
# ...                                        ...
# 2710                                    GoKwik
# 2711                                    Proeon
# 2714                                Voxelgrids
# 2715                        Cogos Technologies
# 2716                                  Gigforce
#
#                                  Sector Main Sector industry         Stage  \
# 257                              Others         NaN      NaN          Seed
# 258                              Others         NaN      NaN          Seed
# 259                              Others         NaN      NaN          Seed
# 294                              Others         NaN      NaN         Angel
# ...

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### Loading Data with initial statistics

# %%
# Load the clean data with a specified encoding
data = pd.read_csv('./dataset/clean_data.csv', encoding='latin1')

# Inspect the first few rows
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2144 entries, 0 to 2143
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company_Brand       2144 non-null   object
#  1   Sector              2144 non-null   object
#  2   Main Sector         2144 non-null   object
#  3   industry            2144 non-null   object
#  4   Stage               1565 non-null   object
#  5   Amount              2144 non-null   float64
#  6   HeadQuarter         2047 non-null   object
#  7   What it does        2144 non-null   object
#  8   Year                2144 non-null   int64
#  9   Founded             2144 non-null   int64
#  10  Founders            1600 non-null   object
#  11  Investor            1540 non-null   object
#  12  Years of Existence  2144 non-null   int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 217.9+ KB

# %%
# Export the data to a CSV file
data.to_csv('./dataset/clean_data.csv', index=False)

# %% [markdown]
# ### Univariate Analysis and cleaning

# %%
# Check summary statistics
data.describe()
# Out:
#              Amount         Year      Founded  Years of Existence
# count  2.144000e+03  2144.000000  2144.000000         2144.000000
# mean   1.010986e+08  2019.827892  2017.215951            2.611940
# std    3.239380e+09     1.152305     1.675635            1.387756
# min    8.760000e+02  2018.000000  2014.000000            0.000000
# 25%    1.000000e+06  2019.000000  2016.000000            2.000000
# 50%    3.800000e+06  2020.000000  2016.000000            2.000000
# 75%    3.000000e+07  2021.000000  2019.000000            4.000000
# max    1.500000e+11  2021.000000  2021.000000            5.000000

# %% [markdown]
# #### Amount:
# - There are 2,144 non-null values in this column.
# - The mean amount is approximately $101,098,600.
# - The standard deviation is approximately $3,239,380.
# - The minimum amount is $876, and the maximum amount is $150,000,000,000.
# - The 25th percentile amount is $1,000,000, the median amount is $3,800,000, and the 75th percentile amount is $30,000,000.
#
# #### Year:
# - There are 2,144 non-null values in this column.
# - The mean year is approximately 2019.83.
# - The standard deviation is approximately 1.15.
# - The minimum year is 2018, and the maximum year is 2021.
# - The 25th percentile year is 2019, the median year is 2020, and the 75th percentile year is 2021.
#
# #### Founded:
# - There are 2,144 non-null values in this column.
# - The mean founding year is approximately 2017.22.
# - The standard deviation is approximately 1.68.
# - The minimum founding year is 2014, and the maximum founding year is 2021.
# - The 25th percentile founding year is 2016, the median founding year is 2016, and the 75th percentile founding year is 2019.
#
# #### Years of Existence:
# - There are 2,144 non-null values in this column.
# - The mean years of existence is approximately 2.61.
# - The standard deviation is approximately 1.39.
# - The minimum years of existence is 0, and the maximum years of existence is 5.
# - The 25th percentile years of existence is 2, the median years of existence is 2, and the 75th percentile years of existence is 4.

# %% [markdown]
# The dataset contains a mix of numerical and categorical data, with some missing values in several columns such as 'Sector', 'Stage', 'HeadQuarter', 'Founders', and 'Investor'. The 'Amount' column is represented as float64, 'Year' and 'Founded' columns are represented as int64, and the rest are of type object.

# %% [markdown]
# #### Checking for duplicates

# %%
# Check for duplicates in the DataFrame
data[data.duplicated(keep= False)]
# Out:
#            Company_Brand                                             Sector  \
# 166            Krimanshi                              Biotechnology Company
# 167            Krimanshi                              Biotechnology Company
# 235      Evenflow Brands                                     Consumer Goods
# 236      Evenflow Brands                                     Consumer Goods
# 592           PingoLearn                                         E-Learning
# 593           PingoLearn                                         E-Learning
# 681                 Spry                                              Music
# 682                 Spry                                              Music
# 733             Trinkerr                                    Capital Markets
# 734             Trinkerr                                    Capital Markets
# 781        ASQI Advisors                                 Financial Services
# ...

# %%
# Count the number of duplicate rows in the DataFrame
data.duplicated(keep= False).sum()
# Out:
# 28

# %%
# Remove duplicate rows from the DataFrame
data.drop_duplicates(keep='first', inplace=True)

# Count the number of duplicate rows in the DataFrame
data.duplicated(keep= False).sum()
# Out:
# 0

# %%
# copying datasets
backup= data
backup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2130 entries, 0 to 2143
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company_Brand       2130 non-null   object
#  1   Sector              2130 non-null   object
#  2   Main Sector         2130 non-null   object
#  3   industry            2130 non-null   object
#  4   Stage               1555 non-null   object
#  5   Amount              2130 non-null   float64
#  6   HeadQuarter         2033 non-null   object
#  7   What it does        2130 non-null   object
#  8   Year                2130 non-null   int64
#  9   Founded             2130 non-null   int64
#  10  Founders            1587 non-null   object
#  11  Investor            1528 non-null   object
#  12  Years of Existence  2130 non-null   int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 233.0+ KB

# %%
# Export the DataFrame to a CSV file
backup.to_csv('./dataset/backup.csv', index=False)

# %% [markdown]
# ##### Distribution of Numeric Columns:

# %%
# Set up the figure and axis
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16, 5))

# Distribution of 'Amount' column
sns.histplot(data['Amount'], bins=20, kde=True, ax=axes[0])
axes[0].set_title('Distribution of Amount')

# Distribution of 'Year' column
sns.histplot(data['Year'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Distribution of Year')

# Distribution of 'Founded' column
sns.histplot(data['Founded'], bins=20, kde=True, ax=axes[2])
axes[2].set_title('Distribution of Founded')

# Distribution of 'Years of Existence' column
sns.histplot(data['Years of Existence'], bins=20, kde=True, ax=axes[3])
axes[3].set_title('Distribution of Years of Existence')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Univariate analysis for categorical columns

# %%
# Univariate analysis for categorical columns
categorical_columns = ['Main Sector', 'industry']

for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data[column])
    plt.title(f'Frequency Counts for {column}')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %%
# Univariate analysis for categorical columns
categorical_columns = ['Stage', 'HeadQuarter']

for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=data, y=column, order=data[column].value_counts().iloc[:20].index)
    plt.title(f'Top 20 Frequency Counts for {column}')
    plt.xlabel('Frequency')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# ##### Frequency Counts for Categorical Columns:

# %%
# Frequency counts for categorical columns
print("Frequency counts for 'Sector' column:")
data['Sector'].value_counts()
# Out:
# Frequency counts for 'Sector' column:
# Sector
# Fintech                                                                 193
# Edtech                                                                  135
# Financial Services                                                       60
# E-Commerce                                                               47
# Healthtech                                                               46
#                                                                        ...
# Crowdsourcing                                                             1
# Crowdsourcing, Financial Services, Funding Platform, Venture Capital      1
# Equity Management                                                         1
# Finance, Financial Exchanges, Financial Services, Micro Lending           1
# Food Startup                                                              1
# Name: count, Length: 751, dtype: int64

# %% [markdown]
# #### Multivariate Analysis

# %% [markdown]
# ##### Categorical vs. Numerical

# %%
# Categorical vs. Numerical
plt.figure(figsize=(18, 20))

# Adjust vertical space between subplots
plt.subplots_adjust(hspace=0.5)

# Categorical: Main Sector vs. Numerical: Amount (Column Chart)
plt.subplot(4, 2, 1)
top_10_main_sector = data['Main Sector'].value_counts().head(10).index
sns.barplot(x='Main Sector', y='Amount', data=data[data['Main Sector'].isin(top_10_main_sector)])
plt.title('Main Sector vs. Amount')
plt.xticks(rotation=45, ha='right')   

# Categorical: Main Sector vs. Numerical: Years of Existence (Column Chart)
plt.subplot(4, 2, 2)
sns.barplot(x='Main Sector', y='Years of Existence', data=data[data['Main Sector'].isin(top_10_main_sector)])
plt.title('Main Sector vs. Years of Existence')
plt.xticks(rotation=45, ha='right')

# Categorical: Industry vs. Numerical: Amount (Column Chart)
plt.subplot(4, 2, 3)
top_10_industry = data['industry'].value_counts().head(10).index
sns.barplot(x='industry', y='Amount', data=data[data['industry'].isin(top_10_industry)])
plt.title('Industry vs. Amount')
plt.xticks(rotation=45, ha='right')  

# Categorical: Top 10 Stage vs. Numerical: Amount (Column Chart)
plt.subplot(4, 2, 4)
top_10_stage = data['Stage'].value_counts().head(10).index
sns.barplot(x='Stage', y='Amount', data=data[data['Stage'].isin(top_10_stage)])
plt.title('Top 10 Stage vs. Amount')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Numerical vs. Numerical

# %%
# Numerical vs. Numerical
plt.figure(figsize=(15, 5))

# Founded vs. Years of Existence
plt.subplot(1, 3, 3)
sns.scatterplot(x='Founded', y='Years of Existence', data=data)
plt.title('Founded vs. Years of Existence')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## BUSINESS QUESTIONS

# %% [markdown]
# ### 1. Distribution of funding across industries:

# %%
# Sort the DataFrame by the total funding amount for each industry in descending order
industry_total_funding = data.groupby('industry')['Amount'].sum().sort_values(ascending=False).reset_index()

# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(y='Amount', x='industry', data=industry_total_funding)
plt.title('Total Funding by Industry')
plt.xlabel('Industry')
plt.ylabel('Total Funding Amount (in USD)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# #### It can be seen that the finance industry dominated the others in terms of receiving funding.

# %% [markdown]
# ### 2. Cities or regions in India that have garnered the highest investments for startups.

# %%
# Group the data by city or region and calculate the total funding amount for each
funding_by_city = data.groupby('HeadQuarter')['Amount'].sum().reset_index()

# Sort the data in descending order based on total funding amount
funding_by_city_sorted = funding_by_city.sort_values(by='Amount', ascending=False)

# Plotting the total funding amount by city or region
plt.figure(figsize=(12, 8))
sns.barplot(x='Amount', y='HeadQuarter', data=funding_by_city_sorted[:5], palette='viridis')
plt.title('Total Funding by City or Region (Top 5)')
plt.xlabel('Total Funding Amount (in USD)')
plt.ylabel('City or Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### It was also found out that Mumbai had by far the greatest funding in terms of Amount received. the next four are Bangalore. New Delhi, Deli and Pune

# %% [markdown]
# ### 3. The major investors in the Indian start-up ecosystem

# %%
# Plotting the frequency of investments by investor
plt.figure(figsize=(12, 8))
sns.countplot(y='Investor', data=data, order=data['Investor'].value_counts().index[:20], palette='muted')
plt.title('Frequency of Investments by Major Investors (Top 20)')
plt.xlabel('Number of Investments')
plt.ylabel('Investor')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ####  the next was determining the type of investors who pumped in more money. It was realised that Inflection point type of investors pumped in more money. Mumbai Angeln network and Angel Inbestors were next to them with almost same amount of money pushed into startups. Titan Capital and investors who were undiscloded were the next set of investors who pushed in more money.

# %% [markdown]
# ### The 3 major investors and industries they love to invest in.

# %%
# Grouping the data by investor and industry, and counting the number of investments
investor_industry_count = data.groupby(['Investor', 'industry']).size().reset_index(name='Investment Count')

# Sorting the data by investment count in descending order
investor_industry_count_sorted = investor_industry_count.sort_values(by='Investment Count', ascending=False)

# Getting the top 3 major investors
top_investors = investor_industry_count_sorted['Investor'].value_counts().head(3).index.tolist()

# Creating bar plots for each major investor
for investor in top_investors:
    investor_data = investor_industry_count_sorted[investor_industry_count_sorted['Investor'] == investor].head(3)
    plt.figure(figsize=(10, 6))
    sns.barplot(y='industry', x='Investment Count', data=investor_data, palette='muted')
    plt.title(f'Top 3 Industries Invested in by {investor}')
    plt.xlabel('Investment Count')
    plt.ylabel('Industry')
    plt.show()

# %% [markdown]
# #### The 3 major investors in the Indian start-up ecosystem and the industries they love to invest. Inflection Point ventures love to invest in ascending order the following industries : Techhnology(7), Business(5) and Education(5). Mumbai Angels Network invested most in Transport, Hospitality and Education (2 each). The third major investor, Ventue Catalysts invested in 6 each of Food & Beverages nad 5 for Technology.

# %% [markdown]
# ### 4. The emerging main sector industries gaining traction among investors.

# %%
# Grouping the data by Main Sector and Year, and counting the number of investments
main_sector_year_count = data.groupby(['Main Sector', 'Year']).size().reset_index(name='Investment Count')

# Sorting the data by investment count in descending order
main_sector_year_count_sorted = main_sector_year_count.sort_values(by='Investment Count', ascending=False)

# Getting the top 3 emerging Main sectors
top_main_sectors = main_sector_year_count_sorted['Main Sector'].value_counts().head(3).index.tolist()

# Creating a bar plot for each top Main sector
for main_sector in top_main_sectors:
    sector_data = main_sector_year_count_sorted[main_sector_year_count_sorted['Main Sector'] == main_sector]
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Year', y='Investment Count', data=sector_data, palette='muted')
    plt.title(f'Investment Trend in {main_sector}')
    plt.xlabel('Year')
    plt.ylabel('Investment Count')
    plt.show()

# %% [markdown]
# #### Emerging main sector  gaining traction among investors: The first main sector gaining tractions from investors by counts is Technology. they had 70, 10, 140 and 120 companies. The second is AI, they had 10, 2, 40 and 8 from 2018 to 2021. finally the next main sector that was emerging as receiving funding was Fintech, 30, 2, 118 and 58 across the years.

# %% [markdown]
# ### 5. The top 3 main sectors within the top 3 industries in terms of funding.

# %%
# Grouping the data by industry and Main Sector, and calculating the total funding
industry_main_sector_funding = data.groupby(['industry', 'Main Sector'])['Amount'].sum().reset_index()

# Sorting the data by industry and total funding in descending order
industry_main_sector_funding_sorted = industry_main_sector_funding.sort_values(by=['industry', 'Amount'], ascending=False)

# Getting the top 3 industries by total funding
top_industries = industry_main_sector_funding_sorted['industry'].value_counts().head(3).index.tolist()

# Creating a grouped bar plot for each top industry
for industry in top_industries:
    industry_data = industry_main_sector_funding_sorted[industry_main_sector_funding_sorted['industry'] == industry].head(3)
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Amount', y='Main Sector', data=industry_data, palette='muted', orient='h')
    plt.title(f'Top 3 Main Sectors in {industry} by Funding')
    plt.xlabel('Total Funding (in USD)')
    plt.ylabel('Main Sector')
    plt.show()

# %% [markdown]
# #### The top 3 Main sectors in terms of funding received within the top 3 industries(Business,Technology, Transport) in terms of funding. Business engulfed Business which was followed by E-commerce, Media & technology. For Technology, technology itself dominated the main sectors which was followed by Ai and then Ar/Vr. For the trandport industry, the most dominating sectors were transport & logistics, automobile and aviation respectively.

# %% [markdown]
# ## HYPOTHESIS TEST

# %%
from scipy.stats import shapiro, levene

#  data
data = np.random.normal(loc=0, scale=1, size=100)

# Shapiro-Wilk Test for normality
shapiro_stat, shapiro_p = shapiro(data)
print("Shapiro-Wilk Test for Normality:")
print("Test Statistic:", shapiro_stat)
print("p-value:", shapiro_p)



# Levene's Test for homogeneity of variances (example with 3 groups)
group1 = np.random.normal(loc=0, scale=1, size=50)
group2 = np.random.normal(loc=0.5, scale=1.5, size=50)
group3 = np.random.normal(loc=-0.5, scale=0.5, size=50)

levene_stat, levene_p = levene(group1, group2, group3)
print("Levene's Test for Homogeneity of Variances:")
print("Test Statistic:", levene_stat)
print("p-value:", levene_p)
# Out:
# Shapiro-Wilk Test for Normality:
# Test Statistic: 0.9797033454441578
# p-value: 0.12604438942159218
# Levene's Test for Homogeneity of Variances:
# Test Statistic: 17.146016908878025
# p-value: 2.0276271709466613e-07

# %% [markdown]
# 1. Shapiro-Wilk Test for Normality:
#    The test statistic calculated by the Shapiro-Wilk test measures the discrepancy between the observed data and what we would expect under the assumption of normality. A higher value indicates closer adherence to normality.
#   The p-value is the probability associated with the test statistic. It indicates the likelihood of obtaining the observed data if the null hypothesis A higher p-value suggests weaker evidence against the null hypothesis.
#
#
#   In this case, the p-value (0.126) is greater than the chosen significance level (usually 0.05), indicating that  the data is normally distributed.
#
# 2. Levene's Test for Homogeneity of Variances:
#    Test Statistic: This is the test statistic calculated by Levene's test measures the discrepancy between the variances of the groups being compared. A higher value indicates greater variability between the group variances.
#    The p-value is the probability associated with the test statistic. It indicates the likelihood of obtaining the observed data if the null hypothesis (all group variances are equal) were true. A lower p-value suggests stronger evidence against the null hypothesis.
#
#
# Given these results:
#
# If the assumption of normality holds (based on the Shapiro-Wilk test), and the assumption of homogeneity of variances is met (based on Levene's test), you can use ANOVA.
# If the assumption of normality is violated, or the assumption of homogeneity of variances is not met, you should use the Kruskal-Wallis H test, which is a non-parametric alternative to ANOVA.
# In this case, since the assumption of homogeneity of variances is violated (p-value < 0.05),
# ### we choose to use the Kruskal-Wallis H test.

# %%
from scipy.stats import kruskal



sector_groups = [data[data['Main Sector'] == sector]['Amount'] for sector in data['Main Sector'].unique()]


# Perform Kruskal-Wallis H-test
h_statistic, p_value = kruskal(*sector_groups)

# Print the results
print("Kruskal-Wallis H-test Results:")
print("H-statistic:", h_statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a difference in funding amounts across different sectors.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in funding amounts across different sectors.")
# Out:
# Kruskal-Wallis H-test Results:
# H-statistic: 38.90176303821631
# p-value: 0.014482048046735597
# Reject the null hypothesis: There is a difference in funding amounts across different sectors.

# %% [markdown]
# #  Based on the Kruskal-Wallis H-test results, we can conclude that there is indeed a difference in funding amounts across different sectors.

# %%
import pandas as pd
data_df.to_csv('data_df.csv', index=False)
